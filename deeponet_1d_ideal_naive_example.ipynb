# %%
import math
import joblib
import keras

import numpy as np
import scipy as sp
import pandas as pd
import tensorflow as tf
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from keras import activations, layers, initializers
from keras.models import Model
from keras.optimizers.legacy import Adam

from src.inn_layers_v2 import IntAdd, IntDense, IntConv2D, IntDropout, IntFlatten, IntMultiply, IntSilu, IntGelu
from src.inn_layers_v2 import IntZeroPadding2D, IntBatchNormalization, IntRelu, IntTanh, IntMultiply_donet
from src.deeponet_wrapper import trainer

from matplotlib import pyplot as plt
import matplotlib.patches as patches
from src import inn_layers_v2 as innv2
from src import grid_augmentation as ga
from src import clust_augmentation as ca

import scienceplots
plt.style.use('science')

import warnings
warnings.filterwarnings("ignore")

# %%
params = {'xtick.labelsize':12,
          'ytick.labelsize':12,
          'axes.labelsize': 16,
          'axes.titlesize': 18}
plt.rcParams.update(params)

# %% [markdown]
# ## Standard precise dataset

# %%
u_in = np.load("data/poisson1Dinput.npy")
g_out = np.load("data/poisson1Doutput.npy") * 20  # the output from u_in_lo is actually lower

y_space = np.linspace(0,1,u_in.shape[1])

# %% [markdown]
# ## Ground truth interval data

# %%
u_in_lo = np.load("data/poisson1Dinput_low.npy")
u_in_hi = np.load("data/poisson1Dinput_high.npy")

g_out_lo = np.load("data/poisson1Doutput_high.npy") * 20  # the output from u_in_lo is actually lower
g_out_hi = np.load("data/poisson1Doutput_low.npy") * 20

# %%
u_int_0 = np.stack([u_in_lo, u_in_hi], axis=-1)
g_int_0 = np.stack([g_out_lo, g_out_hi], axis=-1)

# %% [markdown]
# ### Train-Test split

# %%
n_total = u_in.shape[0] #2000
n_test = 1000  # thus, n_train = 500
n_val = 100
rand = 42
idxs = np.arange(u_in.shape[0])
idx_train, idx_test = train_test_split(idxs, test_size=n_test/n_total, 
                                        random_state=rand)
idx_val, idx_test = train_test_split(idx_test, train_size=n_val/n_test, 
                                        random_state=rand)

# %%
u_int = np.expand_dims(u_int_0, axis=1)
g_int = np.expand_dims(g_int_0, axis=2)

# %%
## Pointwise data split
u_train, u_val, u_test = u_in[idx_train,...], u_in[idx_val,...], u_in[idx_test,...]
g_train, g_val, g_test = g_out[idx_train,...], g_out[idx_val,...], g_out[idx_test,...]

## Interval data split
u_int_train, u_int_val, u_int_test = u_int[idx_train,...], u_int[idx_val,...], u_int[idx_test,...]
g_int_train, g_int_val, g_int_test = g_int[idx_train,...], g_int[idx_val,...], g_int[idx_test,...]

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 5, 20)]

fig2, ax1 = plt.subplots(figsize = (10, 4), dpi=300)
fig2.suptitle('1D Stochastic PDE - Input')

index = 0
i = 42
color = 'tab:red'
ax1.set_xlabel(r'$x$')
ax1.set_ylabel(r'$u(x)$')
ax1.plot(y_space, u_int_test[i,:,:,0].T, '--', color=color)
line1 = ax1.plot(y_space, u_test[i,:].T, '-', color=color, label=r'$u(x)$')
ax1.plot(y_space, u_int_test[i,:,:,1].T, '--', color=color)

ax2 = ax1.twinx()

color = 'tab:blue'
ax2.set_ylabel(r'$g(x)$')
ax2.plot(y_space, g_int_test[i,:,:,0], '--', color=color)
line2 = ax2.plot(y_space, g_test[i,:].T, '-', color=color, label=r'$g(x)$')
ax2.plot(y_space, g_int_test[i,:,:,1], '--', color=color)
ax2.set_ylim(-0.4, 1.2)

# Combine legends from both axes
lines = [line1[0], line2[0]]
labels = [line.get_label() for line in lines]
plt.legend(lines, labels, loc='upper right', ncol=4, labelspacing=0.25, 
           columnspacing=0.25, handletextpad=0.5, handlelength=1)

plt.grid(True)
plt.margins(0)

plt.savefig("img/ideal_1dPDE.pdf", dpi=300, format="pdf")
plt.show()

# %% [markdown]
# ## DeepONet

# %%
def build_mlp(inputs, output_features: int, 
              hidden_features: int, num_hidden_layers: int):
    """
    Builds an MLP regression model.
    
    Parameters:
        x: Input tensor.
        output_features (int): Number of output features.
        hidden_features (int): Number of units in each hidden layer.
        num_hidden_layers (int): Number of hidden layers.
    
    Returns:
        array: keras tensor.
    """
    x = inputs
    
    # Create hidden layers with tanh activation
    for i in range(num_hidden_layers):
        x = layers.Dense(hidden_features, activation='silu', name=f"trunk_{i}")(x)

    # Output layer with linear activation for regression
    outputs = layers.Dense(output_features, activation='linear', name="trunk_final")(x)
    
    return outputs

def build_nimlp(inputs, output_features: int, 
              hidden_features: int, num_hidden_layers: int):
    """
    Builds an Interval MLP regression model.
    
    Parameters:
        x: Input tensor.
        output_features (int): Number of output features.
        hidden_features (int): Number of units in each hidden layer.
        num_hidden_layers (int): Number of hidden layers.
    
    Returns:
        array: keras tensor.
    """
    x = inputs
    
    # Create hidden layers with tanh activation
    for i in range(num_hidden_layers):
        x = layers.Dense(hidden_features, activation="silu", name=f"branch_{i}")(x)

    # Output layer with linear activation for regression
    outputs = layers.Dense(output_features,  activation='linear', name="branch_final")(x)
    
    return outputs

# %%
def interval_deeponet(y_in_size, u_in_size, trunk_params, branch_params, out_feat=1):
    """_summary_

    Args:
        y_in_size (tuple): spatial input size
        u_in_size (tuple): function input size
        trunk_params (dict): trunk net parameters
        branch_params (dict): branch net parameters
        out_feat (int, optional): number of output feature. Defaults to 1.

    Returns:
        keras.Model: output model
    """
    y_input = layers.Input(y_in_size, name="y_input")
    u_input = layers.Input(u_in_size, name="u_input")

    # Trunk layer
    # y_in_lo = y_input[...,0]
    # y_in_hi = y_input[...,1]
    # y_in = [y_in_lo, y_in_hi]
    trunk_out = build_mlp(y_input, trunk_params["output_features"], 
                          trunk_params["hidden_features"], trunk_params["num_hidden_layers"])
    
    # Branch layer
    branch_out = build_nimlp(u_input, branch_params["output_features"], 
                                branch_params["hidden_features"], branch_params["num_hidden_layers"])

    # Multiply trunk and branch
    first_u = layers.Lambda(lambda t: t[..., 0:branch_params["output_features"]//2])(branch_out)  # shape = (batch_size, 64)
    second_u = layers.Lambda(lambda t: t[..., branch_params["output_features"]//2:branch_params["output_features"]])(branch_out) # shape = (batch_size, 64)
    mult1 = layers.Multiply()([trunk_out, first_u])
    mult2 = layers.Multiply()([trunk_out, second_u])
    merged = layers.Concatenate(axis=-1)([mult1, mult2])

    out = layers.Dense(out_feat, name="output_layer")(merged)

    model = Model(inputs=[y_input, u_input], outputs=out, name="DeepONet")

    return model

# %%
trunk_params=dict()
trunk_params["output_features"] = 64
trunk_params["hidden_features"] = 64
trunk_params["num_hidden_layers"] = 4

branch_params=dict()
branch_params["output_features"] = 128
branch_params["hidden_features"] = 64
branch_params["num_hidden_layers"] = 4

# %%
onet = interval_deeponet(y_in_size=(100,1), u_in_size=(1,200), trunk_params=trunk_params, 
                branch_params=branch_params, out_feat=2)
onet.summary()
# Out:
# 2025-08-22 20:32:25.669134: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-08-22 20:32:25.669165: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-08-22 20:32:25.669169: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-08-22 20:32:25.669355: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-08-22 20:32:25.669369: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "DeepONet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  u_input (InputLayer)        [(None, 1, 200)]             0         []
#
#  y_input (InputLayer)        [(None, 100, 1)]             0         []
#
#  branch_0 (Dense)            (None, 1, 64)                12864     ['u_input[0][0]']
#
#  trunk_0 (Dense)             (None, 100, 64)              128       ['y_input[0][0]']
#
#  branch_1 (Dense)            (None, 1, 64)                4160      ['branch_0[0][0]']
#
#  trunk_1 (Dense)             (None, 100, 64)              4160      ['trunk_0[0][0]']
#
#  branch_2 (Dense)            (None, 1, 64)                4160      ['branch_1[0][0]']
#
#  trunk_2 (Dense)             (None, 100, 64)              4160      ['trunk_1[0][0]']
#
#  branch_3 (Dense)            (None, 1, 64)                4160      ['branch_2[0][0]']
#
#  trunk_3 (Dense)             (None, 100, 64)              4160      ['trunk_2[0][0]']
#
#  branch_final (Dense)        (None, 1, 128)               8320      ['branch_3[0][0]']
#
#  trunk_final (Dense)         (None, 100, 64)              4160      ['trunk_3[0][0]']
#
#  lambda (Lambda)             (None, 1, 64)                0         ['branch_final[0][0]']
#
#  lambda_1 (Lambda)           (None, 1, 64)                0         ['branch_final[0][0]']
#
#  multiply (Multiply)         (None, 100, 64)              0         ['trunk_final[0][0]',
#                                                                      'lambda[0][0]']
#
#  multiply_1 (Multiply)       (None, 100, 64)              0         ['trunk_final[0][0]',
#                                                                      'lambda_1[0][0]']
#
#  concatenate (Concatenate)   (None, 100, 128)             0         ['multiply[0][0]',
#                                                                      'multiply_1[0][0]']
#
#  output_layer (Dense)        (None, 100, 2)               258       ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 50690 (198.01 KB)
# Trainable params: 50690 (198.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
def linex_loss(d,a):
    """Linear-exponential loss"""
    b = 2
    term1 = (tf.exp(-a*d)+(a*d)-1)
    return b*term1
    
def custom_loss(target, y_pred):
    term1 = tf.square((target[...,0,0] - y_pred[...,0]))
    term2 = tf.square((target[...,0,1] - y_pred[...,1]))
    loss = tf.reduce_mean(term1+term2)

    return loss

# %%
y_space_train = np.expand_dims(np.tile(y_space,(u_int_train.shape[0],1)), axis=-1)
y_space_val = np.expand_dims(np.tile(y_space,(u_int_val.shape[0],1)), axis=-1)
y_space_test = np.expand_dims(np.tile(y_space,(u_int_test.shape[0],1)), axis=-1)

# %%
class DelayedBestWeights(tf.keras.callbacks.Callback):
    def __init__(self, monitor='loss', mode='min', start_epoch=100):
        super().__init__()
        self.monitor = monitor
        self.mode = mode
        self.start_epoch = start_epoch
        self.best_value = np.inf if mode == 'min' else -np.inf
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_value = logs.get(self.monitor)
        if epoch >= self.start_epoch:
            if (self.mode == 'min' and current_value < self.best_value) or \
               (self.mode == 'max' and current_value > self.best_value):
                self.best_value = current_value
                self.best_weights = self.model.get_weights()
                print(f" Best weights updated at epoch {epoch+1} with {self.monitor}={current_value:.4f}")

    def on_train_end(self, logs=None):
        if self.best_weights is not None:
            self.model.set_weights(self.best_weights)
            print(f"Restored best model from epoch after {self.start_epoch} "
                  f"with {self.monitor}={self.best_value:.4f}")
        else:
            print(f"No improvement found after epoch {self.start_epoch}")

# %%
def run_experiment(trunk_params, branch_params, u_int_train, y_int_train, g_int_train,
                   u_int_val, y_int_val, g_int_val,
                   u_int_test, y_int_test, g_int_test,
                   repetitions=10, n_train = 500, epochs=500, verbose=False):
    """Run the experiment with the given model and data."""

    results = []

    # Choose n_train random as training data
    for seed in tqdm(range(repetitions)):
        # Compile model
        model = interval_deeponet(y_in_size=(100,1), u_in_size=(1,200), trunk_params=trunk_params, 
                branch_params=branch_params, out_feat=2)
        model.compile(
            optimizer=keras.optimizers.legacy.Adam(learning_rate=1e-3),
            loss=custom_loss
        )

        data = dict()
        np.random.seed(seed)
        idx = np.random.choice(np.arange(u_int_train.shape[0]), size=n_train, replace=False)
        u_train_int = u_int_train[idx,...]
        y_train_int = y_int_train[idx,...]
        g_train_int = g_int_train[idx,...]

        u_int_train_in = np.concatenate([u_train_int[...,0], u_train_int[...,1]], axis=-1)
        u_int_val_in = np.concatenate([u_int_val[...,0], u_int_val[...,1]], axis=-1)

        best_weights_cb = DelayedBestWeights(monitor='val_loss', mode='min', start_epoch=100)

        # Train model
        hist = model.fit(x=[y_train_int, u_int_train_in], y=g_train_int, 
                   validation_data=([y_int_val, u_int_val_in], g_int_val), 
                   epochs=epochs, callbacks=[best_weights_cb], verbose=verbose)

        # Evaluate model
        u_int_test_in = np.concatenate([u_int_test[...,0], u_int_test[...,1]], axis=-1)
        pred = model.predict([y_int_test, u_int_test_in])
        data["u_train"] = u_train_int
        data["y_train"] = y_train_int
        data["g_train"] = g_train_int
        data["u_test"] = u_int_test
        data["y_test"] = y_int_test
        data["g_test"] = g_int_test
        data["pred"] = pred
        data["history"] = hist.history

        results.append(data)
        
    return results

# %%
results = run_experiment(trunk_params, branch_params, u_int_train, y_space_train, g_int_train,
                   u_int_val, y_space_val, g_int_val,
                   u_int_test, y_space_test, g_int_test,
                   repetitions=10, n_train=500, epochs=600, verbose=0)
joblib.dump(results, "output/deeponet1d_ideal_naive_ntrain500.pkl")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]2025-08-22 20:32:26.686353: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
#  Best weights updated at epoch 101 with val_loss=0.0158
#  Best weights updated at epoch 102 with val_loss=0.0157
#  Best weights updated at epoch 103 with val_loss=0.0151
#  Best weights updated at epoch 104 with val_loss=0.0150
#  Best weights updated at epoch 110 with val_loss=0.0150
#  Best weights updated at epoch 112 with val_loss=0.0148
#  Best weights updated at epoch 125 with val_loss=0.0144
#  Best weights updated at epoch 127 with val_loss=0.0143
#  Best weights updated at epoch 129 with val_loss=0.0142
#  Best weights updated at epoch 130 with val_loss=0.0141
#  Best weights updated at epoch 131 with val_loss=0.0141
#  Best weights updated at epoch 139 with val_loss=0.0140
#  Best weights updated at epoch 140 with val_loss=0.0137
#  Best weights updated at epoch 142 with val_loss=0.0137
#  Best weights updated at epoch 151 with val_loss=0.0134
#  Best weights updated at epoch 153 with val_loss=0.0132
#  Best weights updated at epoch 154 with val_loss=0.0131
#  Best weights updated at epoch 156 with val_loss=0.0127
#  Best weights updated at epoch 158 with val_loss=0.0125
#  Best weights updated at epoch 160 with val_loss=0.0124
#  Best weights updated at epoch 161 with val_loss=0.0118
#  Best weights updated at epoch 166 with val_loss=0.0117
#  Best weights updated at epoch 171 with val_loss=0.0099
#  Best weights updated at epoch 173 with val_loss=0.0071
#  Best weights updated at epoch 176 with val_loss=0.0062
#  Best weights updated at epoch 177 with val_loss=0.0062
#  Best weights updated at epoch 192 with val_loss=0.0059
#  Best weights updated at epoch 193 with val_loss=0.0055
#  Best weights updated at epoch 195 with val_loss=0.0052
#  Best weights updated at epoch 196 with val_loss=0.0050
#  Best weights updated at epoch 197 with val_loss=0.0049
#  Best weights updated at epoch 198 with val_loss=0.0048
#  Best weights updated at epoch 204 with val_loss=0.0048
#  Best weights updated at epoch 206 with val_loss=0.0047
#  Best weights updated at epoch 234 with val_loss=0.0046
#  Best weights updated at epoch 235 with val_loss=0.0045
#  Best weights updated at epoch 236 with val_loss=0.0044
#  Best weights updated at epoch 239 with val_loss=0.0043
#  Best weights updated at epoch 240 with val_loss=0.0043
#  Best weights updated at epoch 242 with val_loss=0.0043
#  Best weights updated at epoch 244 with val_loss=0.0042
#  Best weights updated at epoch 259 with val_loss=0.0042
#  Best weights updated at epoch 262 with val_loss=0.0041
#  Best weights updated at epoch 333 with val_loss=0.0040
#  Best weights updated at epoch 335 with val_loss=0.0038
#  Best weights updated at epoch 336 with val_loss=0.0037
#  Best weights updated at epoch 338 with val_loss=0.0037
#  Best weights updated at epoch 340 with val_loss=0.0037
#  Best weights updated at epoch 341 with val_loss=0.0035
#  Best weights updated at epoch 342 with val_loss=0.0035
#  Best weights updated at epoch 344 with val_loss=0.0035
#  Best weights updated at epoch 360 with val_loss=0.0033
#  Best weights updated at epoch 361 with val_loss=0.0024
#  Best weights updated at epoch 373 with val_loss=0.0021
#  Best weights updated at epoch 374 with val_loss=0.0019
#  Best weights updated at epoch 375 with val_loss=0.0019
#  Best weights updated at epoch 376 with val_loss=0.0018
#  Best weights updated at epoch 392 with val_loss=0.0018
#  Best weights updated at epoch 394 with val_loss=0.0018
#  Best weights updated at epoch 396 with val_loss=0.0018
#  Best weights updated at epoch 433 with val_loss=0.0017
#  Best weights updated at epoch 439 with val_loss=0.0016
#  Best weights updated at epoch 441 with val_loss=0.0016
#  Best weights updated at epoch 443 with val_loss=0.0016
#  Best weights updated at epoch 447 with val_loss=0.0016
#  Best weights updated at epoch 448 with val_loss=0.0016
#  Best weights updated at epoch 456 with val_loss=0.0016
#  Best weights updated at epoch 512 with val_loss=0.0016
#  Best weights updated at epoch 564 with val_loss=0.0016
#  Best weights updated at epoch 566 with val_loss=0.0016
#  Best weights updated at epoch 575 with val_loss=0.0015
# Restored best model from epoch after 100 with val_loss=0.0015
# 29/29 [==============================] - 1s 16ms/step
#  10%|█         | 1/10 [04:54<44:12, 294.75s/it]
#  Best weights updated at epoch 101 with val_loss=0.0155
#  Best weights updated at epoch 113 with val_loss=0.0154
#  Best weights updated at epoch 114 with val_loss=0.0152
#  Best weights updated at epoch 115 with val_loss=0.0151
#  Best weights updated at epoch 117 with val_loss=0.0150
#  Best weights updated at epoch 118 with val_loss=0.0150
#  Best weights updated at epoch 121 with val_loss=0.0148
#  Best weights updated at epoch 142 with val_loss=0.0134
#  Best weights updated at epoch 143 with val_loss=0.0121
#  Best weights updated at epoch 145 with val_loss=0.0107
#  Best weights updated at epoch 147 with val_loss=0.0106
#  Best weights updated at epoch 148 with val_loss=0.0087
#  Best weights updated at epoch 152 with val_loss=0.0081
#  Best weights updated at epoch 157 with val_loss=0.0075
#  Best weights updated at epoch 158 with val_loss=0.0064
#  Best weights updated at epoch 161 with val_loss=0.0063
#  Best weights updated at epoch 162 with val_loss=0.0062
#  Best weights updated at epoch 164 with val_loss=0.0058
#  Best weights updated at epoch 165 with val_loss=0.0056
#  Best weights updated at epoch 167 with val_loss=0.0056
#  Best weights updated at epoch 168 with val_loss=0.0055
#  Best weights updated at epoch 171 with val_loss=0.0054
#  Best weights updated at epoch 172 with val_loss=0.0054
#  Best weights updated at epoch 173 with val_loss=0.0053
#  Best weights updated at epoch 180 with val_loss=0.0052
#  Best weights updated at epoch 189 with val_loss=0.0052
#  Best weights updated at epoch 212 with val_loss=0.0050
#  Best weights updated at epoch 214 with val_loss=0.0048
#  Best weights updated at epoch 215 with val_loss=0.0048
#  Best weights updated at epoch 218 with val_loss=0.0046
#  Best weights updated at epoch 219 with val_loss=0.0046
#  Best weights updated at epoch 220 with val_loss=0.0044
#  Best weights updated at epoch 224 with val_loss=0.0044
#  Best weights updated at epoch 230 with val_loss=0.0044
#  Best weights updated at epoch 232 with val_loss=0.0042
#  Best weights updated at epoch 255 with val_loss=0.0041
#  Best weights updated at epoch 260 with val_loss=0.0041
#  Best weights updated at epoch 261 with val_loss=0.0040
#  Best weights updated at epoch 281 with val_loss=0.0039
#  Best weights updated at epoch 286 with val_loss=0.0034
#  Best weights updated at epoch 302 with val_loss=0.0030
#  Best weights updated at epoch 303 with val_loss=0.0030
#  Best weights updated at epoch 314 with val_loss=0.0024
#  Best weights updated at epoch 317 with val_loss=0.0022
#  Best weights updated at epoch 318 with val_loss=0.0022
#  Best weights updated at epoch 320 with val_loss=0.0021
#  Best weights updated at epoch 322 with val_loss=0.0020
#  Best weights updated at epoch 377 with val_loss=0.0020
#  Best weights updated at epoch 379 with val_loss=0.0019
#  Best weights updated at epoch 380 with val_loss=0.0019
#  Best weights updated at epoch 383 with val_loss=0.0019
#  Best weights updated at epoch 385 with val_loss=0.0019
#  Best weights updated at epoch 393 with val_loss=0.0019
#  Best weights updated at epoch 394 with val_loss=0.0019
#  Best weights updated at epoch 395 with val_loss=0.0018
#  Best weights updated at epoch 400 with val_loss=0.0018
#  Best weights updated at epoch 401 with val_loss=0.0018
#  Best weights updated at epoch 402 with val_loss=0.0017
#  Best weights updated at epoch 403 with val_loss=0.0017
#  Best weights updated at epoch 464 with val_loss=0.0017
#  Best weights updated at epoch 515 with val_loss=0.0017
#  Best weights updated at epoch 517 with val_loss=0.0017
#  Best weights updated at epoch 530 with val_loss=0.0017
#  Best weights updated at epoch 597 with val_loss=0.0016
# Restored best model from epoch after 100 with val_loss=0.0016
# 29/29 [==============================] - 1s 18ms/step
#  20%|██        | 2/10 [09:37<38:19, 287.43s/it]
#  Best weights updated at epoch 101 with val_loss=0.0166
#  Best weights updated at epoch 111 with val_loss=0.0164
#  Best weights updated at epoch 112 with val_loss=0.0161
#  Best weights updated at epoch 113 with val_loss=0.0160
#  Best weights updated at epoch 114 with val_loss=0.0160
#  Best weights updated at epoch 132 with val_loss=0.0159
#  Best weights updated at epoch 135 with val_loss=0.0158
#  Best weights updated at epoch 146 with val_loss=0.0158
#  Best weights updated at epoch 147 with val_loss=0.0157
#  Best weights updated at epoch 148 with val_loss=0.0156
#  Best weights updated at epoch 149 with val_loss=0.0155
#  Best weights updated at epoch 150 with val_loss=0.0154
#  Best weights updated at epoch 166 with val_loss=0.0153
#  Best weights updated at epoch 181 with val_loss=0.0153
#  Best weights updated at epoch 184 with val_loss=0.0152
#  Best weights updated at epoch 185 with val_loss=0.0150
#  Best weights updated at epoch 186 with val_loss=0.0149
#  Best weights updated at epoch 188 with val_loss=0.0149
#  Best weights updated at epoch 190 with val_loss=0.0148
#  Best weights updated at epoch 191 with val_loss=0.0148
#  Best weights updated at epoch 194 with val_loss=0.0147
#  Best weights updated at epoch 206 with val_loss=0.0147
#  Best weights updated at epoch 222 with val_loss=0.0147
#  Best weights updated at epoch 230 with val_loss=0.0145
#  Best weights updated at epoch 231 with val_loss=0.0119
#  Best weights updated at epoch 232 with val_loss=0.0114
#  Best weights updated at epoch 233 with val_loss=0.0093
#  Best weights updated at epoch 239 with val_loss=0.0086
#  Best weights updated at epoch 240 with val_loss=0.0085
#  Best weights updated at epoch 241 with val_loss=0.0081
#  Best weights updated at epoch 245 with val_loss=0.0075
#  Best weights updated at epoch 246 with val_loss=0.0065
#  Best weights updated at epoch 247 with val_loss=0.0063
#  Best weights updated at epoch 250 with val_loss=0.0061
#  Best weights updated at epoch 251 with val_loss=0.0061
#  Best weights updated at epoch 252 with val_loss=0.0060
#  Best weights updated at epoch 253 with val_loss=0.0060
#  Best weights updated at epoch 254 with val_loss=0.0059
#  Best weights updated at epoch 261 with val_loss=0.0058
#  Best weights updated at epoch 278 with val_loss=0.0057
#  Best weights updated at epoch 279 with val_loss=0.0056
#  Best weights updated at epoch 280 with val_loss=0.0055
#  Best weights updated at epoch 283 with val_loss=0.0054
#  Best weights updated at epoch 305 with val_loss=0.0053
#  Best weights updated at epoch 338 with val_loss=0.0051
#  Best weights updated at epoch 339 with val_loss=0.0050
#  Best weights updated at epoch 349 with val_loss=0.0050
#  Best weights updated at epoch 351 with val_loss=0.0047
#  Best weights updated at epoch 353 with val_loss=0.0047
#  Best weights updated at epoch 356 with val_loss=0.0046
#  Best weights updated at epoch 375 with val_loss=0.0046
#  Best weights updated at epoch 376 with val_loss=0.0045
#  Best weights updated at epoch 378 with val_loss=0.0044
#  Best weights updated at epoch 390 with val_loss=0.0044
#  Best weights updated at epoch 394 with val_loss=0.0044
#  Best weights updated at epoch 424 with val_loss=0.0042
#  Best weights updated at epoch 425 with val_loss=0.0042
#  Best weights updated at epoch 430 with val_loss=0.0041
#  Best weights updated at epoch 432 with val_loss=0.0041
#  Best weights updated at epoch 436 with val_loss=0.0040
#  Best weights updated at epoch 437 with val_loss=0.0040
#  Best weights updated at epoch 438 with val_loss=0.0039
#  Best weights updated at epoch 439 with val_loss=0.0039
#  Best weights updated at epoch 446 with val_loss=0.0039
#  Best weights updated at epoch 448 with val_loss=0.0038
#  Best weights updated at epoch 450 with val_loss=0.0033
#  Best weights updated at epoch 461 with val_loss=0.0033
#  Best weights updated at epoch 463 with val_loss=0.0033
#  Best weights updated at epoch 464 with val_loss=0.0030
#  Best weights updated at epoch 465 with val_loss=0.0028
#  Best weights updated at epoch 466 with val_loss=0.0027
#  Best weights updated at epoch 468 with val_loss=0.0025
#  Best weights updated at epoch 469 with val_loss=0.0024
#  Best weights updated at epoch 472 with val_loss=0.0024
#  Best weights updated at epoch 477 with val_loss=0.0023
#  Best weights updated at epoch 478 with val_loss=0.0022
#  Best weights updated at epoch 479 with val_loss=0.0022
#  Best weights updated at epoch 480 with val_loss=0.0021
#  Best weights updated at epoch 481 with val_loss=0.0020
#  Best weights updated at epoch 483 with val_loss=0.0020
#  Best weights updated at epoch 519 with val_loss=0.0019
#  Best weights updated at epoch 521 with val_loss=0.0019
#  Best weights updated at epoch 526 with val_loss=0.0018
#  Best weights updated at epoch 568 with val_loss=0.0018
#  Best weights updated at epoch 570 with val_loss=0.0018
# Restored best model from epoch after 100 with val_loss=0.0018
# 29/29 [==============================] - 1s 20ms/step
#  30%|███       | 3/10 [14:10<32:47, 281.14s/it]
#  Best weights updated at epoch 101 with val_loss=0.0177
#  Best weights updated at epoch 102 with val_loss=0.0169
#  Best weights updated at epoch 103 with val_loss=0.0165
#  Best weights updated at epoch 113 with val_loss=0.0163
#  Best weights updated at epoch 115 with val_loss=0.0162
#  Best weights updated at epoch 118 with val_loss=0.0161
#  Best weights updated at epoch 119 with val_loss=0.0161
#  Best weights updated at epoch 120 with val_loss=0.0160
#  Best weights updated at epoch 121 with val_loss=0.0160
#  Best weights updated at epoch 132 with val_loss=0.0158
#  Best weights updated at epoch 135 with val_loss=0.0157
#  Best weights updated at epoch 148 with val_loss=0.0156
#  Best weights updated at epoch 149 with val_loss=0.0156
#  Best weights updated at epoch 150 with val_loss=0.0155
#  Best weights updated at epoch 176 with val_loss=0.0154
#  Best weights updated at epoch 177 with val_loss=0.0151
#  Best weights updated at epoch 180 with val_loss=0.0150
#  Best weights updated at epoch 181 with val_loss=0.0150
#  Best weights updated at epoch 192 with val_loss=0.0148
#  Best weights updated at epoch 193 with val_loss=0.0148
#  Best weights updated at epoch 194 with val_loss=0.0147
#  Best weights updated at epoch 200 with val_loss=0.0147
#  Best weights updated at epoch 207 with val_loss=0.0144
#  Best weights updated at epoch 212 with val_loss=0.0144
#  Best weights updated at epoch 214 with val_loss=0.0143
#  Best weights updated at epoch 234 with val_loss=0.0109
#  Best weights updated at epoch 235 with val_loss=0.0103
#  Best weights updated at epoch 236 with val_loss=0.0100
#  Best weights updated at epoch 237 with val_loss=0.0091
#  Best weights updated at epoch 239 with val_loss=0.0076
#  Best weights updated at epoch 242 with val_loss=0.0071
#  Best weights updated at epoch 243 with val_loss=0.0064
#  Best weights updated at epoch 244 with val_loss=0.0063
#  Best weights updated at epoch 247 with val_loss=0.0058
#  Best weights updated at epoch 254 with val_loss=0.0055
#  Best weights updated at epoch 261 with val_loss=0.0055
#  Best weights updated at epoch 268 with val_loss=0.0049
#  Best weights updated at epoch 269 with val_loss=0.0049
#  Best weights updated at epoch 283 with val_loss=0.0048
#  Best weights updated at epoch 286 with val_loss=0.0047
#  Best weights updated at epoch 292 with val_loss=0.0047
#  Best weights updated at epoch 304 with val_loss=0.0046
#  Best weights updated at epoch 310 with val_loss=0.0046
#  Best weights updated at epoch 312 with val_loss=0.0046
#  Best weights updated at epoch 315 with val_loss=0.0044
#  Best weights updated at epoch 317 with val_loss=0.0044
#  Best weights updated at epoch 318 with val_loss=0.0042
#  Best weights updated at epoch 320 with val_loss=0.0042
#  Best weights updated at epoch 354 with val_loss=0.0041
#  Best weights updated at epoch 355 with val_loss=0.0041
#  Best weights updated at epoch 363 with val_loss=0.0041
#  Best weights updated at epoch 367 with val_loss=0.0041
#  Best weights updated at epoch 369 with val_loss=0.0041
#  Best weights updated at epoch 370 with val_loss=0.0040
#  Best weights updated at epoch 372 with val_loss=0.0039
#  Best weights updated at epoch 374 with val_loss=0.0039
#  Best weights updated at epoch 375 with val_loss=0.0039
#  Best weights updated at epoch 399 with val_loss=0.0038
#  Best weights updated at epoch 409 with val_loss=0.0036
#  Best weights updated at epoch 410 with val_loss=0.0035
#  Best weights updated at epoch 411 with val_loss=0.0034
#  Best weights updated at epoch 432 with val_loss=0.0031
#  Best weights updated at epoch 433 with val_loss=0.0025
#  Best weights updated at epoch 444 with val_loss=0.0024
#  Best weights updated at epoch 457 with val_loss=0.0022
#  Best weights updated at epoch 459 with val_loss=0.0021
#  Best weights updated at epoch 460 with val_loss=0.0020
#  Best weights updated at epoch 463 with val_loss=0.0019
#  Best weights updated at epoch 480 with val_loss=0.0019
#  Best weights updated at epoch 481 with val_loss=0.0018
#  Best weights updated at epoch 482 with val_loss=0.0018
#  Best weights updated at epoch 525 with val_loss=0.0017
#  Best weights updated at epoch 531 with val_loss=0.0017
#  Best weights updated at epoch 534 with val_loss=0.0017
#  Best weights updated at epoch 580 with val_loss=0.0017
#  Best weights updated at epoch 584 with val_loss=0.0016
#  Best weights updated at epoch 594 with val_loss=0.0016
# Restored best model from epoch after 100 with val_loss=0.0016
# 29/29 [==============================] - 1s 24ms/step
#  40%|████      | 4/10 [18:58<28:23, 283.88s/it]
#  Best weights updated at epoch 101 with val_loss=0.0178
#  Best weights updated at epoch 102 with val_loss=0.0176
#  Best weights updated at epoch 103 with val_loss=0.0173
#  Best weights updated at epoch 104 with val_loss=0.0171
#  Best weights updated at epoch 118 with val_loss=0.0171
#  Best weights updated at epoch 119 with val_loss=0.0169
#  Best weights updated at epoch 120 with val_loss=0.0166
#  Best weights updated at epoch 127 with val_loss=0.0165
#  Best weights updated at epoch 128 with val_loss=0.0164
#  Best weights updated at epoch 130 with val_loss=0.0164
#  Best weights updated at epoch 135 with val_loss=0.0162
#  Best weights updated at epoch 141 with val_loss=0.0161
#  Best weights updated at epoch 142 with val_loss=0.0161
#  Best weights updated at epoch 143 with val_loss=0.0159
#  Best weights updated at epoch 144 with val_loss=0.0159
#  Best weights updated at epoch 164 with val_loss=0.0157
#  Best weights updated at epoch 165 with val_loss=0.0156
#  Best weights updated at epoch 168 with val_loss=0.0156
#  Best weights updated at epoch 169 with val_loss=0.0155
#  Best weights updated at epoch 170 with val_loss=0.0154
#  Best weights updated at epoch 173 with val_loss=0.0154
#  Best weights updated at epoch 174 with val_loss=0.0152
#  Best weights updated at epoch 190 with val_loss=0.0150
#  Best weights updated at epoch 191 with val_loss=0.0149
#  Best weights updated at epoch 193 with val_loss=0.0148
#  Best weights updated at epoch 212 with val_loss=0.0140
#  Best weights updated at epoch 217 with val_loss=0.0134
#  Best weights updated at epoch 218 with val_loss=0.0119
#  Best weights updated at epoch 219 with val_loss=0.0106
#  Best weights updated at epoch 220 with val_loss=0.0099
#  Best weights updated at epoch 223 with val_loss=0.0093
#  Best weights updated at epoch 234 with val_loss=0.0081
#  Best weights updated at epoch 236 with val_loss=0.0070
#  Best weights updated at epoch 238 with val_loss=0.0068
#  Best weights updated at epoch 239 with val_loss=0.0064
#  Best weights updated at epoch 241 with val_loss=0.0063
#  Best weights updated at epoch 242 with val_loss=0.0061
#  Best weights updated at epoch 243 with val_loss=0.0061
#  Best weights updated at epoch 249 with val_loss=0.0061
#  Best weights updated at epoch 250 with val_loss=0.0059
#  Best weights updated at epoch 258 with val_loss=0.0058
#  Best weights updated at epoch 284 with val_loss=0.0057
#  Best weights updated at epoch 286 with val_loss=0.0057
#  Best weights updated at epoch 287 with val_loss=0.0056
#  Best weights updated at epoch 288 with val_loss=0.0056
#  Best weights updated at epoch 289 with val_loss=0.0056
#  Best weights updated at epoch 290 with val_loss=0.0056
#  Best weights updated at epoch 291 with val_loss=0.0055
#  Best weights updated at epoch 299 with val_loss=0.0054
#  Best weights updated at epoch 300 with val_loss=0.0054
#  Best weights updated at epoch 301 with val_loss=0.0053
#  Best weights updated at epoch 303 with val_loss=0.0053
#  Best weights updated at epoch 304 with val_loss=0.0053
#  Best weights updated at epoch 306 with val_loss=0.0053
#  Best weights updated at epoch 307 with val_loss=0.0053
#  Best weights updated at epoch 309 with val_loss=0.0052
#  Best weights updated at epoch 311 with val_loss=0.0052
#  Best weights updated at epoch 314 with val_loss=0.0052
#  Best weights updated at epoch 342 with val_loss=0.0051
#  Best weights updated at epoch 344 with val_loss=0.0050
#  Best weights updated at epoch 350 with val_loss=0.0050
#  Best weights updated at epoch 355 with val_loss=0.0049
#  Best weights updated at epoch 356 with val_loss=0.0048
#  Best weights updated at epoch 358 with val_loss=0.0047
#  Best weights updated at epoch 361 with val_loss=0.0046
#  Best weights updated at epoch 362 with val_loss=0.0046
#  Best weights updated at epoch 363 with val_loss=0.0046
#  Best weights updated at epoch 366 with val_loss=0.0045
#  Best weights updated at epoch 376 with val_loss=0.0045
#  Best weights updated at epoch 377 with val_loss=0.0045
#  Best weights updated at epoch 404 with val_loss=0.0044
#  Best weights updated at epoch 407 with val_loss=0.0044
#  Best weights updated at epoch 413 with val_loss=0.0042
#  Best weights updated at epoch 414 with val_loss=0.0041
#  Best weights updated at epoch 426 with val_loss=0.0041
#  Best weights updated at epoch 431 with val_loss=0.0041
#  Best weights updated at epoch 446 with val_loss=0.0040
#  Best weights updated at epoch 458 with val_loss=0.0039
#  Best weights updated at epoch 459 with val_loss=0.0033
#  Best weights updated at epoch 463 with val_loss=0.0031
#  Best weights updated at epoch 469 with val_loss=0.0024
#  Best weights updated at epoch 473 with val_loss=0.0020
#  Best weights updated at epoch 476 with val_loss=0.0019
#  Best weights updated at epoch 479 with val_loss=0.0019
#  Best weights updated at epoch 483 with val_loss=0.0018
#  Best weights updated at epoch 503 with val_loss=0.0018
#  Best weights updated at epoch 504 with val_loss=0.0018
#  Best weights updated at epoch 506 with val_loss=0.0017
#  Best weights updated at epoch 514 with val_loss=0.0017
#  Best weights updated at epoch 520 with val_loss=0.0017
#  Best weights updated at epoch 569 with val_loss=0.0016
#  Best weights updated at epoch 593 with val_loss=0.0016
# Restored best model from epoch after 100 with val_loss=0.0016
# 29/29 [==============================] - 1s 23ms/step
#  50%|█████     | 5/10 [23:51<23:55, 287.19s/it]
#  Best weights updated at epoch 101 with val_loss=0.0194
#  Best weights updated at epoch 102 with val_loss=0.0184
#  Best weights updated at epoch 109 with val_loss=0.0177
#  Best weights updated at epoch 110 with val_loss=0.0171
#  Best weights updated at epoch 113 with val_loss=0.0168
#  Best weights updated at epoch 121 with val_loss=0.0164
#  Best weights updated at epoch 132 with val_loss=0.0163
#  Best weights updated at epoch 133 with val_loss=0.0163
#  Best weights updated at epoch 134 with val_loss=0.0162
#  Best weights updated at epoch 138 with val_loss=0.0161
#  Best weights updated at epoch 143 with val_loss=0.0159
#  Best weights updated at epoch 144 with val_loss=0.0159
#  Best weights updated at epoch 145 with val_loss=0.0159
#  Best weights updated at epoch 147 with val_loss=0.0159
#  Best weights updated at epoch 152 with val_loss=0.0158
#  Best weights updated at epoch 159 with val_loss=0.0157
#  Best weights updated at epoch 160 with val_loss=0.0157
#  Best weights updated at epoch 205 with val_loss=0.0157
#  Best weights updated at epoch 206 with val_loss=0.0153
#  Best weights updated at epoch 207 with val_loss=0.0153
#  Best weights updated at epoch 208 with val_loss=0.0151
#  Best weights updated at epoch 210 with val_loss=0.0150
#  Best weights updated at epoch 218 with val_loss=0.0150
#  Best weights updated at epoch 219 with val_loss=0.0149
#  Best weights updated at epoch 220 with val_loss=0.0148
#  Best weights updated at epoch 223 with val_loss=0.0148
#  Best weights updated at epoch 224 with val_loss=0.0148
#  Best weights updated at epoch 226 with val_loss=0.0148
#  Best weights updated at epoch 227 with val_loss=0.0147
#  Best weights updated at epoch 234 with val_loss=0.0146
#  Best weights updated at epoch 237 with val_loss=0.0146
#  Best weights updated at epoch 239 with val_loss=0.0145
#  Best weights updated at epoch 260 with val_loss=0.0141
#  Best weights updated at epoch 262 with val_loss=0.0139
#  Best weights updated at epoch 263 with val_loss=0.0138
#  Best weights updated at epoch 264 with val_loss=0.0135
#  Best weights updated at epoch 265 with val_loss=0.0134
#  Best weights updated at epoch 266 with val_loss=0.0132
#  Best weights updated at epoch 267 with val_loss=0.0131
#  Best weights updated at epoch 268 with val_loss=0.0128
#  Best weights updated at epoch 269 with val_loss=0.0125
#  Best weights updated at epoch 270 with val_loss=0.0121
#  Best weights updated at epoch 271 with val_loss=0.0111
#  Best weights updated at epoch 272 with val_loss=0.0109
#  Best weights updated at epoch 279 with val_loss=0.0096
#  Best weights updated at epoch 284 with val_loss=0.0085
#  Best weights updated at epoch 285 with val_loss=0.0074
#  Best weights updated at epoch 287 with val_loss=0.0071
#  Best weights updated at epoch 288 with val_loss=0.0069
#  Best weights updated at epoch 289 with val_loss=0.0060
#  Best weights updated at epoch 291 with val_loss=0.0056
#  Best weights updated at epoch 292 with val_loss=0.0055
#  Best weights updated at epoch 297 with val_loss=0.0054
#  Best weights updated at epoch 304 with val_loss=0.0054
#  Best weights updated at epoch 305 with val_loss=0.0053
#  Best weights updated at epoch 306 with val_loss=0.0052
#  Best weights updated at epoch 307 with val_loss=0.0050
#  Best weights updated at epoch 310 with val_loss=0.0049
#  Best weights updated at epoch 322 with val_loss=0.0049
#  Best weights updated at epoch 323 with val_loss=0.0048
#  Best weights updated at epoch 324 with val_loss=0.0047
#  Best weights updated at epoch 343 with val_loss=0.0046
#  Best weights updated at epoch 364 with val_loss=0.0046
#  Best weights updated at epoch 365 with val_loss=0.0045
#  Best weights updated at epoch 366 with val_loss=0.0045
#  Best weights updated at epoch 367 with val_loss=0.0044
#  Best weights updated at epoch 368 with val_loss=0.0043
#  Best weights updated at epoch 369 with val_loss=0.0043
#  Best weights updated at epoch 370 with val_loss=0.0042
#  Best weights updated at epoch 382 with val_loss=0.0042
#  Best weights updated at epoch 387 with val_loss=0.0041
#  Best weights updated at epoch 388 with val_loss=0.0041
#  Best weights updated at epoch 389 with val_loss=0.0040
#  Best weights updated at epoch 424 with val_loss=0.0040
#  Best weights updated at epoch 427 with val_loss=0.0040
#  Best weights updated at epoch 431 with val_loss=0.0040
#  Best weights updated at epoch 434 with val_loss=0.0039
#  Best weights updated at epoch 435 with val_loss=0.0039
#  Best weights updated at epoch 437 with val_loss=0.0039
#  Best weights updated at epoch 438 with val_loss=0.0038
#  Best weights updated at epoch 439 with val_loss=0.0038
#  Best weights updated at epoch 441 with val_loss=0.0037
#  Best weights updated at epoch 442 with val_loss=0.0037
#  Best weights updated at epoch 444 with val_loss=0.0036
#  Best weights updated at epoch 445 with val_loss=0.0036
#  Best weights updated at epoch 447 with val_loss=0.0036
#  Best weights updated at epoch 448 with val_loss=0.0034
#  Best weights updated at epoch 449 with val_loss=0.0033
#  Best weights updated at epoch 450 with val_loss=0.0033
#  Best weights updated at epoch 451 with val_loss=0.0033
#  Best weights updated at epoch 453 with val_loss=0.0031
#  Best weights updated at epoch 454 with val_loss=0.0031
#  Best weights updated at epoch 471 with val_loss=0.0021
#  Best weights updated at epoch 478 with val_loss=0.0021
#  Best weights updated at epoch 481 with val_loss=0.0020
#  Best weights updated at epoch 482 with val_loss=0.0020
#  Best weights updated at epoch 483 with val_loss=0.0019
#  Best weights updated at epoch 484 with val_loss=0.0017
#  Best weights updated at epoch 534 with val_loss=0.0017
#  Best weights updated at epoch 576 with val_loss=0.0016
#  Best weights updated at epoch 587 with val_loss=0.0016
#  Best weights updated at epoch 590 with val_loss=0.0016
#  Best weights updated at epoch 594 with val_loss=0.0016
# Restored best model from epoch after 100 with val_loss=0.0016
# 29/29 [==============================] - 1s 25ms/step
#  60%|██████    | 6/10 [28:49<19:23, 290.87s/it]
#  Best weights updated at epoch 101 with val_loss=0.0177
#  Best weights updated at epoch 102 with val_loss=0.0175
#  Best weights updated at epoch 103 with val_loss=0.0174
#  Best weights updated at epoch 104 with val_loss=0.0172
#  Best weights updated at epoch 115 with val_loss=0.0171
#  Best weights updated at epoch 116 with val_loss=0.0168
#  Best weights updated at epoch 117 with val_loss=0.0167
#  Best weights updated at epoch 118 with val_loss=0.0166
#  Best weights updated at epoch 119 with val_loss=0.0165
#  Best weights updated at epoch 120 with val_loss=0.0164
#  Best weights updated at epoch 121 with val_loss=0.0163
#  Best weights updated at epoch 126 with val_loss=0.0162
#  Best weights updated at epoch 128 with val_loss=0.0161
#  Best weights updated at epoch 130 with val_loss=0.0160
#  Best weights updated at epoch 138 with val_loss=0.0159
#  Best weights updated at epoch 143 with val_loss=0.0158
#  Best weights updated at epoch 164 with val_loss=0.0157
#  Best weights updated at epoch 165 with val_loss=0.0156
#  Best weights updated at epoch 166 with val_loss=0.0154
#  Best weights updated at epoch 169 with val_loss=0.0153
#  Best weights updated at epoch 183 with val_loss=0.0151
#  Best weights updated at epoch 188 with val_loss=0.0151
#  Best weights updated at epoch 193 with val_loss=0.0149
#  Best weights updated at epoch 221 with val_loss=0.0149
#  Best weights updated at epoch 222 with val_loss=0.0145
#  Best weights updated at epoch 223 with val_loss=0.0144
#  Best weights updated at epoch 224 with val_loss=0.0143
#  Best weights updated at epoch 226 with val_loss=0.0140
#  Best weights updated at epoch 228 with val_loss=0.0137
#  Best weights updated at epoch 229 with val_loss=0.0134
#  Best weights updated at epoch 230 with val_loss=0.0132
#  Best weights updated at epoch 231 with val_loss=0.0128
#  Best weights updated at epoch 232 with val_loss=0.0124
#  Best weights updated at epoch 237 with val_loss=0.0114
#  Best weights updated at epoch 238 with val_loss=0.0094
#  Best weights updated at epoch 245 with val_loss=0.0083
#  Best weights updated at epoch 246 with val_loss=0.0074
#  Best weights updated at epoch 247 with val_loss=0.0065
#  Best weights updated at epoch 252 with val_loss=0.0062
#  Best weights updated at epoch 263 with val_loss=0.0060
#  Best weights updated at epoch 264 with val_loss=0.0060
#  Best weights updated at epoch 265 with val_loss=0.0056
#  Best weights updated at epoch 270 with val_loss=0.0055
#  Best weights updated at epoch 271 with val_loss=0.0054
#  Best weights updated at epoch 275 with val_loss=0.0054
#  Best weights updated at epoch 280 with val_loss=0.0053
#  Best weights updated at epoch 282 with val_loss=0.0052
#  Best weights updated at epoch 314 with val_loss=0.0051
#  Best weights updated at epoch 315 with val_loss=0.0049
#  Best weights updated at epoch 316 with val_loss=0.0048
#  Best weights updated at epoch 318 with val_loss=0.0047
#  Best weights updated at epoch 323 with val_loss=0.0047
#  Best weights updated at epoch 324 with val_loss=0.0046
#  Best weights updated at epoch 327 with val_loss=0.0046
#  Best weights updated at epoch 358 with val_loss=0.0044
#  Best weights updated at epoch 364 with val_loss=0.0044
#  Best weights updated at epoch 366 with val_loss=0.0044
#  Best weights updated at epoch 367 with val_loss=0.0044
#  Best weights updated at epoch 369 with val_loss=0.0042
#  Best weights updated at epoch 372 with val_loss=0.0042
#  Best weights updated at epoch 379 with val_loss=0.0041
#  Best weights updated at epoch 381 with val_loss=0.0041
#  Best weights updated at epoch 413 with val_loss=0.0033
#  Best weights updated at epoch 419 with val_loss=0.0033
#  Best weights updated at epoch 420 with val_loss=0.0029
#  Best weights updated at epoch 425 with val_loss=0.0027
#  Best weights updated at epoch 426 with val_loss=0.0026
#  Best weights updated at epoch 437 with val_loss=0.0023
#  Best weights updated at epoch 446 with val_loss=0.0022
#  Best weights updated at epoch 450 with val_loss=0.0021
#  Best weights updated at epoch 453 with val_loss=0.0020
#  Best weights updated at epoch 454 with val_loss=0.0020
#  Best weights updated at epoch 457 with val_loss=0.0019
#  Best weights updated at epoch 485 with val_loss=0.0018
#  Best weights updated at epoch 492 with val_loss=0.0018
#  Best weights updated at epoch 543 with val_loss=0.0018
#  Best weights updated at epoch 545 with val_loss=0.0017
#  Best weights updated at epoch 546 with val_loss=0.0017
#  Best weights updated at epoch 548 with val_loss=0.0017
#  Best weights updated at epoch 551 with val_loss=0.0017
# Restored best model from epoch after 100 with val_loss=0.0017
# 29/29 [==============================] - 1s 26ms/step
#  70%|███████   | 7/10 [33:45<14:37, 292.57s/it]
#  Best weights updated at epoch 101 with val_loss=0.0169
#  Best weights updated at epoch 105 with val_loss=0.0168
#  Best weights updated at epoch 107 with val_loss=0.0168
#  Best weights updated at epoch 115 with val_loss=0.0167
#  Best weights updated at epoch 124 with val_loss=0.0165
#  Best weights updated at epoch 125 with val_loss=0.0164
#  Best weights updated at epoch 126 with val_loss=0.0163
#  Best weights updated at epoch 135 with val_loss=0.0163
#  Best weights updated at epoch 137 with val_loss=0.0162
#  Best weights updated at epoch 156 with val_loss=0.0160
#  Best weights updated at epoch 157 with val_loss=0.0159
#  Best weights updated at epoch 158 with val_loss=0.0159
#  Best weights updated at epoch 160 with val_loss=0.0158
#  Best weights updated at epoch 161 with val_loss=0.0158
#  Best weights updated at epoch 162 with val_loss=0.0157
#  Best weights updated at epoch 167 with val_loss=0.0155
#  Best weights updated at epoch 169 with val_loss=0.0155
#  Best weights updated at epoch 174 with val_loss=0.0155
#  Best weights updated at epoch 175 with val_loss=0.0154
#  Best weights updated at epoch 176 with val_loss=0.0153
#  Best weights updated at epoch 181 with val_loss=0.0153
#  Best weights updated at epoch 182 with val_loss=0.0153
#  Best weights updated at epoch 203 with val_loss=0.0148
#  Best weights updated at epoch 204 with val_loss=0.0146
#  Best weights updated at epoch 205 with val_loss=0.0144
#  Best weights updated at epoch 208 with val_loss=0.0133
#  Best weights updated at epoch 209 with val_loss=0.0120
#  Best weights updated at epoch 210 with val_loss=0.0120
#  Best weights updated at epoch 217 with val_loss=0.0114
#  Best weights updated at epoch 218 with val_loss=0.0109
#  Best weights updated at epoch 219 with val_loss=0.0091
#  Best weights updated at epoch 222 with val_loss=0.0075
#  Best weights updated at epoch 229 with val_loss=0.0068
#  Best weights updated at epoch 230 with val_loss=0.0062
#  Best weights updated at epoch 231 with val_loss=0.0062
#  Best weights updated at epoch 232 with val_loss=0.0062
#  Best weights updated at epoch 234 with val_loss=0.0061
#  Best weights updated at epoch 235 with val_loss=0.0060
#  Best weights updated at epoch 236 with val_loss=0.0059
#  Best weights updated at epoch 244 with val_loss=0.0058
#  Best weights updated at epoch 245 with val_loss=0.0057
#  Best weights updated at epoch 249 with val_loss=0.0056
#  Best weights updated at epoch 250 with val_loss=0.0054
#  Best weights updated at epoch 268 with val_loss=0.0052
#  Best weights updated at epoch 269 with val_loss=0.0052
#  Best weights updated at epoch 270 with val_loss=0.0050
#  Best weights updated at epoch 277 with val_loss=0.0050
#  Best weights updated at epoch 288 with val_loss=0.0049
#  Best weights updated at epoch 289 with val_loss=0.0049
#  Best weights updated at epoch 301 with val_loss=0.0047
#  Best weights updated at epoch 302 with val_loss=0.0046
#  Best weights updated at epoch 305 with val_loss=0.0046
#  Best weights updated at epoch 342 with val_loss=0.0044
#  Best weights updated at epoch 345 with val_loss=0.0043
#  Best weights updated at epoch 349 with val_loss=0.0043
#  Best weights updated at epoch 351 with val_loss=0.0043
#  Best weights updated at epoch 352 with val_loss=0.0042
#  Best weights updated at epoch 353 with val_loss=0.0042
#  Best weights updated at epoch 410 with val_loss=0.0040
#  Best weights updated at epoch 411 with val_loss=0.0040
#  Best weights updated at epoch 412 with val_loss=0.0039
#  Best weights updated at epoch 413 with val_loss=0.0039
#  Best weights updated at epoch 444 with val_loss=0.0036
#  Best weights updated at epoch 445 with val_loss=0.0033
#  Best weights updated at epoch 453 with val_loss=0.0029
#  Best weights updated at epoch 476 with val_loss=0.0028
#  Best weights updated at epoch 477 with val_loss=0.0025
#  Best weights updated at epoch 479 with val_loss=0.0022
#  Best weights updated at epoch 480 with val_loss=0.0021
#  Best weights updated at epoch 482 with val_loss=0.0021
#  Best weights updated at epoch 483 with val_loss=0.0020
#  Best weights updated at epoch 484 with val_loss=0.0019
#  Best weights updated at epoch 487 with val_loss=0.0018
#  Best weights updated at epoch 500 with val_loss=0.0018
#  Best weights updated at epoch 504 with val_loss=0.0017
#  Best weights updated at epoch 516 with val_loss=0.0017
#  Best weights updated at epoch 562 with val_loss=0.0017
#  Best weights updated at epoch 571 with val_loss=0.0016
#  Best weights updated at epoch 572 with val_loss=0.0016
#  Best weights updated at epoch 575 with val_loss=0.0016
#  Best weights updated at epoch 576 with val_loss=0.0016
#  Best weights updated at epoch 578 with val_loss=0.0016
#  Best weights updated at epoch 580 with val_loss=0.0016
# Restored best model from epoch after 100 with val_loss=0.0016
# 29/29 [==============================] - 1s 24ms/step
#  80%|████████  | 8/10 [38:39<09:45, 292.76s/it]
#  Best weights updated at epoch 101 with val_loss=0.0172
#  Best weights updated at epoch 102 with val_loss=0.0171
#  Best weights updated at epoch 103 with val_loss=0.0169
#  Best weights updated at epoch 106 with val_loss=0.0166
#  Best weights updated at epoch 107 with val_loss=0.0164
#  Best weights updated at epoch 108 with val_loss=0.0164
#  Best weights updated at epoch 109 with val_loss=0.0163
#  Best weights updated at epoch 111 with val_loss=0.0162
#  Best weights updated at epoch 112 with val_loss=0.0162
#  Best weights updated at epoch 117 with val_loss=0.0159
#  Best weights updated at epoch 120 with val_loss=0.0159
#  Best weights updated at epoch 123 with val_loss=0.0159
#  Best weights updated at epoch 124 with val_loss=0.0159
#  Best weights updated at epoch 125 with val_loss=0.0158
#  Best weights updated at epoch 126 with val_loss=0.0158
#  Best weights updated at epoch 134 with val_loss=0.0154
#  Best weights updated at epoch 137 with val_loss=0.0154
#  Best weights updated at epoch 138 with val_loss=0.0152
#  Best weights updated at epoch 148 with val_loss=0.0151
#  Best weights updated at epoch 150 with val_loss=0.0150
#  Best weights updated at epoch 151 with val_loss=0.0149
#  Best weights updated at epoch 152 with val_loss=0.0149
#  Best weights updated at epoch 164 with val_loss=0.0148
#  Best weights updated at epoch 192 with val_loss=0.0144
#  Best weights updated at epoch 204 with val_loss=0.0138
#  Best weights updated at epoch 208 with val_loss=0.0136
#  Best weights updated at epoch 211 with val_loss=0.0136
#  Best weights updated at epoch 212 with val_loss=0.0135
#  Best weights updated at epoch 214 with val_loss=0.0134
#  Best weights updated at epoch 216 with val_loss=0.0134
#  Best weights updated at epoch 217 with val_loss=0.0133
#  Best weights updated at epoch 218 with val_loss=0.0132
#  Best weights updated at epoch 221 with val_loss=0.0131
#  Best weights updated at epoch 222 with val_loss=0.0130
#  Best weights updated at epoch 224 with val_loss=0.0130
#  Best weights updated at epoch 225 with val_loss=0.0128
#  Best weights updated at epoch 226 with val_loss=0.0125
#  Best weights updated at epoch 227 with val_loss=0.0119
#  Best weights updated at epoch 235 with val_loss=0.0109
#  Best weights updated at epoch 236 with val_loss=0.0103
#  Best weights updated at epoch 242 with val_loss=0.0077
#  Best weights updated at epoch 243 with val_loss=0.0056
#  Best weights updated at epoch 250 with val_loss=0.0055
#  Best weights updated at epoch 254 with val_loss=0.0053
#  Best weights updated at epoch 255 with val_loss=0.0052
#  Best weights updated at epoch 256 with val_loss=0.0047
#  Best weights updated at epoch 268 with val_loss=0.0046
#  Best weights updated at epoch 270 with val_loss=0.0044
#  Best weights updated at epoch 272 with val_loss=0.0044
#  Best weights updated at epoch 274 with val_loss=0.0044
#  Best weights updated at epoch 275 with val_loss=0.0043
#  Best weights updated at epoch 279 with val_loss=0.0042
#  Best weights updated at epoch 282 with val_loss=0.0042
#  Best weights updated at epoch 288 with val_loss=0.0042
#  Best weights updated at epoch 321 with val_loss=0.0042
#  Best weights updated at epoch 323 with val_loss=0.0041
#  Best weights updated at epoch 325 with val_loss=0.0041
#  Best weights updated at epoch 361 with val_loss=0.0041
#  Best weights updated at epoch 362 with val_loss=0.0040
#  Best weights updated at epoch 363 with val_loss=0.0039
#  Best weights updated at epoch 364 with val_loss=0.0039
#  Best weights updated at epoch 365 with val_loss=0.0039
#  Best weights updated at epoch 370 with val_loss=0.0039
#  Best weights updated at epoch 372 with val_loss=0.0039
#  Best weights updated at epoch 402 with val_loss=0.0039
#  Best weights updated at epoch 403 with val_loss=0.0038
#  Best weights updated at epoch 407 with val_loss=0.0038
#  Best weights updated at epoch 408 with val_loss=0.0037
#  Best weights updated at epoch 410 with val_loss=0.0037
#  Best weights updated at epoch 411 with val_loss=0.0037
#  Best weights updated at epoch 414 with val_loss=0.0037
#  Best weights updated at epoch 416 with val_loss=0.0037
#  Best weights updated at epoch 417 with val_loss=0.0036
#  Best weights updated at epoch 421 with val_loss=0.0036
#  Best weights updated at epoch 427 with val_loss=0.0036
#  Best weights updated at epoch 428 with val_loss=0.0034
#  Best weights updated at epoch 429 with val_loss=0.0031
#  Best weights updated at epoch 440 with val_loss=0.0031
#  Best weights updated at epoch 441 with val_loss=0.0029
#  Best weights updated at epoch 442 with val_loss=0.0026
#  Best weights updated at epoch 443 with val_loss=0.0024
#  Best weights updated at epoch 457 with val_loss=0.0022
#  Best weights updated at epoch 463 with val_loss=0.0021
#  Best weights updated at epoch 468 with val_loss=0.0021
#  Best weights updated at epoch 478 with val_loss=0.0020
#  Best weights updated at epoch 479 with val_loss=0.0019
#  Best weights updated at epoch 487 with val_loss=0.0018
#  Best weights updated at epoch 535 with val_loss=0.0017
#  Best weights updated at epoch 577 with val_loss=0.0017
#  Best weights updated at epoch 578 with val_loss=0.0017
#  Best weights updated at epoch 580 with val_loss=0.0017
# Restored best model from epoch after 100 with val_loss=0.0017
# 29/29 [==============================] - 2s 31ms/step
#  90%|█████████ | 9/10 [43:29<04:52, 292.10s/it]
#  Best weights updated at epoch 101 with val_loss=0.0572
#  Best weights updated at epoch 102 with val_loss=0.0566
#  Best weights updated at epoch 104 with val_loss=0.0561
#  Best weights updated at epoch 105 with val_loss=0.0552
#  Best weights updated at epoch 106 with val_loss=0.0535
#  Best weights updated at epoch 107 with val_loss=0.0509
#  Best weights updated at epoch 108 with val_loss=0.0458
#  Best weights updated at epoch 109 with val_loss=0.0451
#  Best weights updated at epoch 119 with val_loss=0.0432
#  Best weights updated at epoch 120 with val_loss=0.0372
#  Best weights updated at epoch 121 with val_loss=0.0285
#  Best weights updated at epoch 122 with val_loss=0.0277
#  Best weights updated at epoch 130 with val_loss=0.0244
#  Best weights updated at epoch 131 with val_loss=0.0187
#  Best weights updated at epoch 134 with val_loss=0.0181
#  Best weights updated at epoch 141 with val_loss=0.0172
#  Best weights updated at epoch 142 with val_loss=0.0168
#  Best weights updated at epoch 144 with val_loss=0.0166
#  Best weights updated at epoch 145 with val_loss=0.0165
#  Best weights updated at epoch 147 with val_loss=0.0165
#  Best weights updated at epoch 149 with val_loss=0.0164
#  Best weights updated at epoch 150 with val_loss=0.0164
#  Best weights updated at epoch 151 with val_loss=0.0163
#  Best weights updated at epoch 163 with val_loss=0.0162
#  Best weights updated at epoch 164 with val_loss=0.0161
#  Best weights updated at epoch 167 with val_loss=0.0161
#  Best weights updated at epoch 170 with val_loss=0.0160
#  Best weights updated at epoch 174 with val_loss=0.0159
#  Best weights updated at epoch 180 with val_loss=0.0158
#  Best weights updated at epoch 196 with val_loss=0.0158
#  Best weights updated at epoch 216 with val_loss=0.0158
#  Best weights updated at epoch 218 with val_loss=0.0156
#  Best weights updated at epoch 220 with val_loss=0.0155
#  Best weights updated at epoch 221 with val_loss=0.0155
#  Best weights updated at epoch 223 with val_loss=0.0155
#  Best weights updated at epoch 226 with val_loss=0.0155
#  Best weights updated at epoch 227 with val_loss=0.0154
#  Best weights updated at epoch 230 with val_loss=0.0154
#  Best weights updated at epoch 233 with val_loss=0.0154
#  Best weights updated at epoch 264 with val_loss=0.0152
#  Best weights updated at epoch 267 with val_loss=0.0151
#  Best weights updated at epoch 268 with val_loss=0.0150
#  Best weights updated at epoch 269 with val_loss=0.0150
#  Best weights updated at epoch 271 with val_loss=0.0150
#  Best weights updated at epoch 273 with val_loss=0.0150
#  Best weights updated at epoch 275 with val_loss=0.0149
#  Best weights updated at epoch 278 with val_loss=0.0149
#  Best weights updated at epoch 279 with val_loss=0.0149
#  Best weights updated at epoch 280 with val_loss=0.0148
#  Best weights updated at epoch 281 with val_loss=0.0147
#  Best weights updated at epoch 283 with val_loss=0.0147
#  Best weights updated at epoch 297 with val_loss=0.0145
#  Best weights updated at epoch 298 with val_loss=0.0142
#  Best weights updated at epoch 299 with val_loss=0.0140
#  Best weights updated at epoch 300 with val_loss=0.0136
#  Best weights updated at epoch 301 with val_loss=0.0133
#  Best weights updated at epoch 302 with val_loss=0.0130
#  Best weights updated at epoch 309 with val_loss=0.0125
#  Best weights updated at epoch 317 with val_loss=0.0115
#  Best weights updated at epoch 320 with val_loss=0.0095
#  Best weights updated at epoch 322 with val_loss=0.0091
#  Best weights updated at epoch 323 with val_loss=0.0072
#  Best weights updated at epoch 324 with val_loss=0.0066
#  Best weights updated at epoch 325 with val_loss=0.0061
#  Best weights updated at epoch 333 with val_loss=0.0061
#  Best weights updated at epoch 334 with val_loss=0.0061
#  Best weights updated at epoch 336 with val_loss=0.0060
#  Best weights updated at epoch 337 with val_loss=0.0058
#  Best weights updated at epoch 340 with val_loss=0.0058
#  Best weights updated at epoch 341 with val_loss=0.0058
#  Best weights updated at epoch 357 with val_loss=0.0057
#  Best weights updated at epoch 359 with val_loss=0.0054
#  Best weights updated at epoch 362 with val_loss=0.0054
#  Best weights updated at epoch 363 with val_loss=0.0054
#  Best weights updated at epoch 366 with val_loss=0.0053
#  Best weights updated at epoch 377 with val_loss=0.0052
#  Best weights updated at epoch 404 with val_loss=0.0050
#  Best weights updated at epoch 405 with val_loss=0.0049
#  Best weights updated at epoch 426 with val_loss=0.0048
#  Best weights updated at epoch 427 with val_loss=0.0047
#  Best weights updated at epoch 438 with val_loss=0.0045
#  Best weights updated at epoch 439 with val_loss=0.0045
#  Best weights updated at epoch 440 with val_loss=0.0043
#  Best weights updated at epoch 441 with val_loss=0.0043
#  Best weights updated at epoch 443 with val_loss=0.0042
#  Best weights updated at epoch 462 with val_loss=0.0042
#  Best weights updated at epoch 463 with val_loss=0.0041
#  Best weights updated at epoch 490 with val_loss=0.0041
#  Best weights updated at epoch 491 with val_loss=0.0040
#  Best weights updated at epoch 495 with val_loss=0.0039
#  Best weights updated at epoch 499 with val_loss=0.0038
#  Best weights updated at epoch 500 with val_loss=0.0038
#  Best weights updated at epoch 501 with val_loss=0.0037
#  Best weights updated at epoch 503 with val_loss=0.0037
#  Best weights updated at epoch 504 with val_loss=0.0036
#  Best weights updated at epoch 506 with val_loss=0.0036
#  Best weights updated at epoch 507 with val_loss=0.0035
#  Best weights updated at epoch 523 with val_loss=0.0031
#  Best weights updated at epoch 532 with val_loss=0.0030
#  Best weights updated at epoch 533 with val_loss=0.0026
#  Best weights updated at epoch 546 with val_loss=0.0023
#  Best weights updated at epoch 547 with val_loss=0.0023
#  Best weights updated at epoch 548 with val_loss=0.0021
#  Best weights updated at epoch 551 with val_loss=0.0020
#  Best weights updated at epoch 555 with val_loss=0.0020
#  Best weights updated at epoch 562 with val_loss=0.0020
#  Best weights updated at epoch 563 with val_loss=0.0020
#  Best weights updated at epoch 565 with val_loss=0.0019
#  Best weights updated at epoch 567 with val_loss=0.0019
# Restored best model from epoch after 100 with val_loss=0.0019
# 29/29 [==============================] - 2s 32ms/step
# 100%|██████████| 10/10 [48:22<00:00, 290.25s/it]
# ['output/deeponet1d_ideal_naive_ntrain500.pkl']

# %%
plt.semilogy(results[0]['history']['loss'])

# %% [markdown]
# ## Predict

# %%
idx=9
preds = results[idx]["pred"]
g_int_test = results[idx]["g_test"]

plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 5, 20)]

fig2 = plt.figure(figsize = (10, 4), dpi=300)
fig2.suptitle('1D Stochastic PDE - DeepONet')

index = 0
for i in [39,66,77,99]:
    plt.plot(y_space, g_int_test[i,:,:,0], color=colors[index], label='Actual')
    plt.plot(y_space, g_int_test[i,:,:,1], color=colors[index], label='Actual')
    plt.plot(y_space, preds[i,:,0].T, '--', color=colors[index], label='Prediction')
    plt.plot(y_space, preds[i,:,1].T, '--', color=colors[index], label='Prediction')
    index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)
