# %%
import math
import joblib
import keras

import numpy as np
import scipy as sp
import pandas as pd
import tensorflow as tf
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from keras import activations, layers, initializers
from keras.models import Model
from keras.optimizers.legacy import Adam

from src.inn_layers_v2 import IntAdd, IntDense, IntConv2D, IntDropout, IntFlatten, IntMultiply, IntSilu, IntGelu
from src.inn_layers_v2 import IntZeroPadding2D, IntBatchNormalization, IntRelu, IntTanh, IntMultiply_donet
from src.deeponet_wrapper import trainer

from matplotlib import pyplot as plt
import matplotlib.patches as patches
from src import inn_layers_v2 as innv2
from src import grid_augmentation as ga
from src import clust_augmentation as ca
from timeit import default_timer

import scienceplots
plt.style.use('science')

import warnings
warnings.filterwarnings("ignore")

# %%
params = {'xtick.labelsize':12,
          'ytick.labelsize':12,
          'axes.labelsize': 16,
          'axes.titlesize': 18}
plt.rcParams.update(params)

# %% [markdown]
# ## Standard precise dataset

# %%
u_in = np.load("data/poisson1Dinput.npy")
g_out = np.load("data/poisson1Doutput.npy") * 20  # the output from u_in_lo is actually lower

y_space = np.linspace(0,1,u_in.shape[1])

# %% [markdown]
# ## Ground truth interval data

# %%
u_in_lo = np.load("data/poisson1Dinput_low.npy")
u_in_hi = np.load("data/poisson1Dinput_high.npy")

g_out_lo = np.load("data/poisson1Doutput_high.npy") * 20  # the output from u_in_lo is actually lower
g_out_hi = np.load("data/poisson1Doutput_low.npy") * 20

# %%
u_int_0 = np.stack([u_in_lo, u_in_hi], axis=-1)
g_int_0 = np.stack([g_out_lo, g_out_hi], axis=-1)

# %% [markdown]
# ### Train-Test split

# %%
n_total = u_in.shape[0] #2000
n_test = 1000  # thus, n_train = 500
n_val = 100
rand = 42
idxs = np.arange(u_in.shape[0])
idx_train, idx_test = train_test_split(idxs, test_size=n_test/n_total, 
                                        random_state=rand)
idx_val, idx_test = train_test_split(idx_test, train_size=n_val/n_test, 
                                        random_state=rand)

# %%
u_int = np.expand_dims(u_int_0, axis=1)
g_int = np.expand_dims(g_int_0, axis=2)

# %%
## Pointwise data split
u_train, u_val, u_test = u_in[idx_train,...], u_in[idx_val,...], u_in[idx_test,...]
g_train, g_val, g_test = g_out[idx_train,...], g_out[idx_val,...], g_out[idx_test,...]

## Interval data split
u_int_train, u_int_val, u_int_test = u_int[idx_train,...], u_int[idx_val,...], u_int[idx_test,...]
g_int_train, g_int_val, g_int_test = g_int[idx_train,...], g_int[idx_val,...], g_int[idx_test,...]

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 5, 20)]

fig2, ax1 = plt.subplots(figsize = (10, 4), dpi=300)
fig2.suptitle('1D Stochastic PDE - Input')

index = 0
i = 42
color = 'tab:red'
ax1.set_xlabel(r'$x$')
ax1.set_ylabel(r'$u(x)$')
ax1.plot(y_space, u_int_test[i,:,:,0].T, '--', color=color)
line1 = ax1.plot(y_space, u_test[i,:].T, '-', color=color, label=r'$u(x)$')
ax1.plot(y_space, u_int_test[i,:,:,1].T, '--', color=color)

ax2 = ax1.twinx()

color = 'tab:blue'
ax2.set_ylabel(r'$g(x)$')
ax2.plot(y_space, g_int_test[i,:,:,0], '--', color=color)
line2 = ax2.plot(y_space, g_test[i,:].T, '-', color=color, label=r'$g(x)$')
ax2.plot(y_space, g_int_test[i,:,:,1], '--', color=color)
ax2.set_ylim(-0.4, 1.2)

# Combine legends from both axes
lines = [line1[0], line2[0]]
labels = [line.get_label() for line in lines]
plt.legend(lines, labels, loc='upper right', ncol=4, labelspacing=0.25, 
           columnspacing=0.25, handletextpad=0.5, handlelength=1)

plt.grid(True)
plt.margins(0)

plt.savefig("img/ideal_1dPDE.pdf", dpi=300, format="pdf")
plt.show()

# %% [markdown]
# ## DeepONet

# %%
def build_mlp(inputs, output_features: int, 
              hidden_features: int, num_hidden_layers: int):
    """
    Builds an MLP regression model.
    
    Parameters:
        x: Input tensor.
        output_features (int): Number of output features.
        hidden_features (int): Number of units in each hidden layer.
        num_hidden_layers (int): Number of hidden layers.
    
    Returns:
        array: keras tensor.
    """
    x = inputs
    
    # Create hidden layers with tanh activation
    for i in range(num_hidden_layers):
        x = layers.Dense(hidden_features, activation='silu', name=f"trunk_{i}")(x)

    # Output layer with linear activation for regression
    outputs = layers.Dense(output_features, activation='linear', name="trunk_final")(x)
    
    return outputs

def build_nimlp(inputs, output_features: int, 
              hidden_features: int, num_hidden_layers: int):
    """
    Builds an Interval MLP regression model.
    
    Parameters:
        x: Input tensor.
        output_features (int): Number of output features.
        hidden_features (int): Number of units in each hidden layer.
        num_hidden_layers (int): Number of hidden layers.
    
    Returns:
        array: keras tensor.
    """
    x = inputs
    
    # Create hidden layers with tanh activation
    for i in range(num_hidden_layers):
        x = layers.Dense(hidden_features, activation="silu", name=f"branch_{i}")(x)

    # Output layer with linear activation for regression
    outputs = layers.Dense(output_features,  activation='linear', name="branch_final")(x)
    
    return outputs

# %%
def interval_deeponet(y_in_size, u_in_size, trunk_params, branch_params, out_feat=1):
    """_summary_

    Args:
        y_in_size (tuple): spatial input size
        u_in_size (tuple): function input size
        trunk_params (dict): trunk net parameters
        branch_params (dict): branch net parameters
        out_feat (int, optional): number of output feature. Defaults to 1.

    Returns:
        keras.Model: output model
    """
    y_input = layers.Input(y_in_size, name="y_input")
    u_input = layers.Input(u_in_size, name="u_input")

    # Trunk layer
    # y_in_lo = y_input[...,0]
    # y_in_hi = y_input[...,1]
    # y_in = [y_in_lo, y_in_hi]
    trunk_out = build_mlp(y_input, trunk_params["output_features"], 
                          trunk_params["hidden_features"], trunk_params["num_hidden_layers"])
    
    # Branch layer
    branch_out = build_nimlp(u_input, branch_params["output_features"], 
                                branch_params["hidden_features"], branch_params["num_hidden_layers"])

    # Multiply trunk and branch
    first_u = layers.Lambda(lambda t: t[..., 0:branch_params["output_features"]//2])(branch_out)  # shape = (batch_size, 64)
    second_u = layers.Lambda(lambda t: t[..., branch_params["output_features"]//2:branch_params["output_features"]])(branch_out) # shape = (batch_size, 64)
    mult1 = layers.Multiply()([trunk_out, first_u])
    mult2 = layers.Multiply()([trunk_out, second_u])
    merged = layers.Concatenate(axis=-1)([mult1, mult2])

    out = layers.Dense(out_feat, name="output_layer")(merged)

    model = Model(inputs=[y_input, u_input], outputs=out, name="DeepONet")

    return model

# %%
trunk_params=dict()
trunk_params["output_features"] = 64
trunk_params["hidden_features"] = 64
trunk_params["num_hidden_layers"] = 4

branch_params=dict()
branch_params["output_features"] = 128
branch_params["hidden_features"] = 64
branch_params["num_hidden_layers"] = 4

# %%
onet = interval_deeponet(y_in_size=(100,1), u_in_size=(1,200), trunk_params=trunk_params, 
                branch_params=branch_params, out_feat=2)
onet.summary()
# Out:
# 2026-02-24 13:13:54.145300: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2026-02-24 13:13:54.145326: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-02-24 13:13:54.145330: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2026-02-24 13:13:54.145360: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-02-24 13:13:54.145374: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "DeepONet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  u_input (InputLayer)        [(None, 1, 200)]             0         []
#
#  y_input (InputLayer)        [(None, 100, 1)]             0         []
#
#  branch_0 (Dense)            (None, 1, 64)                12864     ['u_input[0][0]']
#
#  trunk_0 (Dense)             (None, 100, 64)              128       ['y_input[0][0]']
#
#  branch_1 (Dense)            (None, 1, 64)                4160      ['branch_0[0][0]']
#
#  trunk_1 (Dense)             (None, 100, 64)              4160      ['trunk_0[0][0]']
#
#  branch_2 (Dense)            (None, 1, 64)                4160      ['branch_1[0][0]']
#
#  trunk_2 (Dense)             (None, 100, 64)              4160      ['trunk_1[0][0]']
#
#  branch_3 (Dense)            (None, 1, 64)                4160      ['branch_2[0][0]']
#
#  trunk_3 (Dense)             (None, 100, 64)              4160      ['trunk_2[0][0]']
#
#  branch_final (Dense)        (None, 1, 128)               8320      ['branch_3[0][0]']
#
#  trunk_final (Dense)         (None, 100, 64)              4160      ['trunk_3[0][0]']
#
#  lambda (Lambda)             (None, 1, 64)                0         ['branch_final[0][0]']
#
#  lambda_1 (Lambda)           (None, 1, 64)                0         ['branch_final[0][0]']
#
#  multiply (Multiply)         (None, 100, 64)              0         ['trunk_final[0][0]',
#                                                                      'lambda[0][0]']
#
#  multiply_1 (Multiply)       (None, 100, 64)              0         ['trunk_final[0][0]',
#                                                                      'lambda_1[0][0]']
#
#  concatenate (Concatenate)   (None, 100, 128)             0         ['multiply[0][0]',
#                                                                      'multiply_1[0][0]']
#
#  output_layer (Dense)        (None, 100, 2)               258       ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 50690 (198.01 KB)
# Trainable params: 50690 (198.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
def linex_loss(d,a):
    """Linear-exponential loss"""
    b = 2
    term1 = (tf.exp(-a*d)+(a*d)-1)
    return b*term1
    
def custom_loss(target, y_pred):
    term1 = tf.square((target[...,0,0] - y_pred[...,0]))
    term2 = tf.square((target[...,0,1] - y_pred[...,1]))
    loss = tf.reduce_mean(term1+term2)

    return loss

# %%
y_space_train = np.expand_dims(np.tile(y_space,(u_int_train.shape[0],1)), axis=-1)
y_space_val = np.expand_dims(np.tile(y_space,(u_int_val.shape[0],1)), axis=-1)
y_space_test = np.expand_dims(np.tile(y_space,(u_int_test.shape[0],1)), axis=-1)

# %%
class DelayedBestWeights(tf.keras.callbacks.Callback):
    def __init__(self, monitor='loss', mode='min', start_epoch=100):
        super().__init__()
        self.monitor = monitor
        self.mode = mode
        self.start_epoch = start_epoch
        self.best_value = np.inf if mode == 'min' else -np.inf
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_value = logs.get(self.monitor)
        if epoch >= self.start_epoch:
            if (self.mode == 'min' and current_value < self.best_value) or \
               (self.mode == 'max' and current_value > self.best_value):
                self.best_value = current_value
                self.best_weights = self.model.get_weights()
                print(f" Best weights updated at epoch {epoch+1} with {self.monitor}={current_value:.4f}")

    def on_train_end(self, logs=None):
        if self.best_weights is not None:
            self.model.set_weights(self.best_weights)
            print(f"Restored best model from epoch after {self.start_epoch} "
                  f"with {self.monitor}={self.best_value:.4f}")
        else:
            print(f"No improvement found after epoch {self.start_epoch}")

# %%
def run_experiment(trunk_params, branch_params, u_int_train, y_int_train, g_int_train,
                   u_int_val, y_int_val, g_int_val,
                   u_int_test, y_int_test, g_int_test,
                   repetitions=10, n_train = 500, epochs=500, verbose=False):
    """Run the experiment with the given model and data."""

    results = []

    # Choose n_train random as training data
    for seed in tqdm(range(repetitions)):
        # Compile model
        model = interval_deeponet(y_in_size=(100,1), u_in_size=(1,200), trunk_params=trunk_params, 
                branch_params=branch_params, out_feat=2)
        model.compile(
            optimizer=keras.optimizers.legacy.Adam(learning_rate=1e-3),
            loss=custom_loss
        )

        data = dict()
        np.random.seed(seed)
        idx = np.random.choice(np.arange(u_int_train.shape[0]), size=n_train, replace=False)
        u_train_int = u_int_train[idx,...]
        y_train_int = y_int_train[idx,...]
        g_train_int = g_int_train[idx,...]

        u_int_train_in = np.concatenate([u_train_int[...,0], u_train_int[...,1]], axis=-1)
        u_int_val_in = np.concatenate([u_int_val[...,0], u_int_val[...,1]], axis=-1)

        best_weights_cb = DelayedBestWeights(monitor='val_loss', mode='min', start_epoch=100)

        # Train model
        t0 = default_timer()
        hist = model.fit(x=[y_train_int, u_int_train_in], y=g_train_int, 
                   validation_data=([y_int_val, u_int_val_in], g_int_val), 
                   epochs=epochs, callbacks=[best_weights_cb], verbose=verbose, batch_size=128)
        data["training_time"] = default_timer() - t0

        # Evaluate model
        u_int_test_in = np.concatenate([u_int_test[...,0], u_int_test[...,1]], axis=-1)
        t0 = default_timer()
        pred = model.predict([y_int_test, u_int_test_in])
        data["inference_time"] = default_timer() - t0
        
        data["u_train"] = u_train_int
        data["y_train"] = y_train_int
        data["g_train"] = g_train_int
        data["u_test"] = u_int_test
        data["y_test"] = y_int_test
        data["g_test"] = g_int_test
        data["pred"] = pred
        data["history"] = hist.history

        results.append(data)
        
    return results

# %%
for ntrain in [50, 100, 250, 500]:
        results = run_experiment(trunk_params, branch_params, u_int_train, y_space_train, g_int_train,
                        u_int_val, y_space_val, g_int_val,
                        u_int_test, y_space_test, g_int_test,
                        repetitions=10, n_train=ntrain, epochs=1000, verbose=0)
        joblib.dump(results, f"output/deeponet1d/deeponet1d_ideal_naive_ntrain{ntrain}_time.pkl")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2026-02-24 13:13:55.262168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
#  Best weights updated at epoch 101 with val_loss=0.5503
#  Best weights updated at epoch 102 with val_loss=0.5491
#  Best weights updated at epoch 103 with val_loss=0.5476
#  Best weights updated at epoch 104 with val_loss=0.5459
#  Best weights updated at epoch 105 with val_loss=0.5439
#  Best weights updated at epoch 106 with val_loss=0.5418
#  Best weights updated at epoch 107 with val_loss=0.5395
#  Best weights updated at epoch 108 with val_loss=0.5368
#  Best weights updated at epoch 109 with val_loss=0.5338
#  Best weights updated at epoch 110 with val_loss=0.5303
#  Best weights updated at epoch 111 with val_loss=0.5264
#  Best weights updated at epoch 112 with val_loss=0.5221
#  Best weights updated at epoch 113 with val_loss=0.5175
#  Best weights updated at epoch 114 with val_loss=0.5122
#  Best weights updated at epoch 115 with val_loss=0.5061
#  Best weights updated at epoch 116 with val_loss=0.4991
#  Best weights updated at epoch 117 with val_loss=0.4914
#  Best weights updated at epoch 118 with val_loss=0.4829
#  Best weights updated at epoch 119 with val_loss=0.4735
#  Best weights updated at epoch 120 with val_loss=0.4628
#  Best weights updated at epoch 121 with val_loss=0.4514
#  Best weights updated at epoch 122 with val_loss=0.4392
#  Best weights updated at epoch 123 with val_loss=0.4260
#  Best weights updated at epoch 124 with val_loss=0.4119
#  Best weights updated at epoch 125 with val_loss=0.3970
#  Best weights updated at epoch 126 with val_loss=0.3806
#  Best weights updated at epoch 127 with val_loss=0.3632
#  Best weights updated at epoch 128 with val_loss=0.3436
#  Best weights updated at epoch 129 with val_loss=0.3275
#  Best weights updated at epoch 132 with val_loss=0.2724
#  Best weights updated at epoch 134 with val_loss=0.2603
#  Best weights updated at epoch 135 with val_loss=0.2418
#  Best weights updated at epoch 137 with val_loss=0.2027
#  Best weights updated at epoch 140 with val_loss=0.1714
#  Best weights updated at epoch 143 with val_loss=0.1556
#  Best weights updated at epoch 146 with val_loss=0.1543
#  Best weights updated at epoch 149 with val_loss=0.1517
#  Best weights updated at epoch 152 with val_loss=0.1453
#  Best weights updated at epoch 157 with val_loss=0.1447
#  Best weights updated at epoch 159 with val_loss=0.1442
#  Best weights updated at epoch 163 with val_loss=0.1441
#  Best weights updated at epoch 165 with val_loss=0.1439
#  Best weights updated at epoch 167 with val_loss=0.1427
#  Best weights updated at epoch 169 with val_loss=0.1422
#  Best weights updated at epoch 171 with val_loss=0.1411
#  Best weights updated at epoch 172 with val_loss=0.1410
#  Best weights updated at epoch 173 with val_loss=0.1409
#  Best weights updated at epoch 174 with val_loss=0.1405
#  Best weights updated at epoch 175 with val_loss=0.1402
#  Best weights updated at epoch 176 with val_loss=0.1397
#  Best weights updated at epoch 178 with val_loss=0.1392
#  Best weights updated at epoch 180 with val_loss=0.1385
#  Best weights updated at epoch 182 with val_loss=0.1377
#  Best weights updated at epoch 183 with val_loss=0.1376
#  Best weights updated at epoch 184 with val_loss=0.1369
#  Best weights updated at epoch 185 with val_loss=0.1368
#  Best weights updated at epoch 186 with val_loss=0.1360
#  Best weights updated at epoch 187 with val_loss=0.1357
#  Best weights updated at epoch 188 with val_loss=0.1353
#  Best weights updated at epoch 189 with val_loss=0.1349
#  Best weights updated at epoch 190 with val_loss=0.1344
#  Best weights updated at epoch 191 with val_loss=0.1340
#  Best weights updated at epoch 192 with val_loss=0.1338
#  Best weights updated at epoch 193 with val_loss=0.1334
#  Best weights updated at epoch 194 with val_loss=0.1330
#  Best weights updated at epoch 195 with val_loss=0.1326
#  Best weights updated at epoch 196 with val_loss=0.1325
#  Best weights updated at epoch 197 with val_loss=0.1320
#  Best weights updated at epoch 198 with val_loss=0.1317
#  Best weights updated at epoch 199 with val_loss=0.1313
#  Best weights updated at epoch 200 with val_loss=0.1311
#  Best weights updated at epoch 201 with val_loss=0.1306
#  Best weights updated at epoch 202 with val_loss=0.1302
#  Best weights updated at epoch 203 with val_loss=0.1299
#  Best weights updated at epoch 204 with val_loss=0.1296
#  Best weights updated at epoch 205 with val_loss=0.1291
#  Best weights updated at epoch 206 with val_loss=0.1288
#  Best weights updated at epoch 207 with val_loss=0.1284
#  Best weights updated at epoch 208 with val_loss=0.1280
#  Best weights updated at epoch 209 with val_loss=0.1276
#  Best weights updated at epoch 210 with val_loss=0.1272
#  Best weights updated at epoch 211 with val_loss=0.1268
#  Best weights updated at epoch 212 with val_loss=0.1264
#  Best weights updated at epoch 213 with val_loss=0.1260
#  Best weights updated at epoch 214 with val_loss=0.1255
#  Best weights updated at epoch 215 with val_loss=0.1251
#  Best weights updated at epoch 216 with val_loss=0.1247
#  Best weights updated at epoch 217 with val_loss=0.1242
#  Best weights updated at epoch 218 with val_loss=0.1238
#  Best weights updated at epoch 219 with val_loss=0.1234
#  Best weights updated at epoch 220 with val_loss=0.1230
#  Best weights updated at epoch 221 with val_loss=0.1226
#  Best weights updated at epoch 222 with val_loss=0.1222
#  Best weights updated at epoch 223 with val_loss=0.1218
#  Best weights updated at epoch 224 with val_loss=0.1215
#  Best weights updated at epoch 225 with val_loss=0.1211
#  Best weights updated at epoch 226 with val_loss=0.1208
#  Best weights updated at epoch 227 with val_loss=0.1205
#  Best weights updated at epoch 228 with val_loss=0.1202
#  Best weights updated at epoch 229 with val_loss=0.1200
#  Best weights updated at epoch 230 with val_loss=0.1198
#  Best weights updated at epoch 231 with val_loss=0.1196
#  Best weights updated at epoch 232 with val_loss=0.1194
#  Best weights updated at epoch 233 with val_loss=0.1192
#  Best weights updated at epoch 234 with val_loss=0.1191
#  Best weights updated at epoch 235 with val_loss=0.1189
#  Best weights updated at epoch 236 with val_loss=0.1188
#  Best weights updated at epoch 237 with val_loss=0.1187
#  Best weights updated at epoch 238 with val_loss=0.1186
#  Best weights updated at epoch 239 with val_loss=0.1185
#  Best weights updated at epoch 240 with val_loss=0.1184
#  Best weights updated at epoch 241 with val_loss=0.1184
#  Best weights updated at epoch 242 with val_loss=0.1183
#  Best weights updated at epoch 243 with val_loss=0.1182
#  Best weights updated at epoch 244 with val_loss=0.1182
#  Best weights updated at epoch 245 with val_loss=0.1181
#  Best weights updated at epoch 246 with val_loss=0.1180
#  Best weights updated at epoch 247 with val_loss=0.1180
#  Best weights updated at epoch 248 with val_loss=0.1179
#  Best weights updated at epoch 249 with val_loss=0.1179
#  Best weights updated at epoch 250 with val_loss=0.1178
#  Best weights updated at epoch 251 with val_loss=0.1177
#  Best weights updated at epoch 252 with val_loss=0.1177
#  Best weights updated at epoch 253 with val_loss=0.1176
#  Best weights updated at epoch 254 with val_loss=0.1176
#  Best weights updated at epoch 255 with val_loss=0.1175
#  Best weights updated at epoch 256 with val_loss=0.1174
#  Best weights updated at epoch 257 with val_loss=0.1174
#  Best weights updated at epoch 258 with val_loss=0.1173
#  Best weights updated at epoch 259 with val_loss=0.1173
#  Best weights updated at epoch 260 with val_loss=0.1172
#  Best weights updated at epoch 261 with val_loss=0.1172
#  Best weights updated at epoch 262 with val_loss=0.1171
#  Best weights updated at epoch 263 with val_loss=0.1171
#  Best weights updated at epoch 264 with val_loss=0.1170
#  Best weights updated at epoch 265 with val_loss=0.1170
#  Best weights updated at epoch 266 with val_loss=0.1169
#  Best weights updated at epoch 267 with val_loss=0.1169
#  Best weights updated at epoch 268 with val_loss=0.1168
#  Best weights updated at epoch 269 with val_loss=0.1168
#  Best weights updated at epoch 270 with val_loss=0.1167
#  Best weights updated at epoch 271 with val_loss=0.1167
#  Best weights updated at epoch 272 with val_loss=0.1166
#  Best weights updated at epoch 273 with val_loss=0.1166
#  Best weights updated at epoch 274 with val_loss=0.1165
#  Best weights updated at epoch 275 with val_loss=0.1165
#  Best weights updated at epoch 276 with val_loss=0.1164
#  Best weights updated at epoch 277 with val_loss=0.1164
#  Best weights updated at epoch 278 with val_loss=0.1163
#  Best weights updated at epoch 279 with val_loss=0.1163
#  Best weights updated at epoch 280 with val_loss=0.1162
#  Best weights updated at epoch 281 with val_loss=0.1162
#  Best weights updated at epoch 282 with val_loss=0.1162
#  Best weights updated at epoch 283 with val_loss=0.1161
#  Best weights updated at epoch 284 with val_loss=0.1161
#  Best weights updated at epoch 285 with val_loss=0.1160
#  Best weights updated at epoch 286 with val_loss=0.1160
#  Best weights updated at epoch 287 with val_loss=0.1159
#  Best weights updated at epoch 288 with val_loss=0.1159
#  Best weights updated at epoch 289 with val_loss=0.1159
#  Best weights updated at epoch 290 with val_loss=0.1158
#  Best weights updated at epoch 291 with val_loss=0.1158
#  Best weights updated at epoch 292 with val_loss=0.1158
#  Best weights updated at epoch 293 with val_loss=0.1158
#  Best weights updated at epoch 294 with val_loss=0.1157
#  Best weights updated at epoch 295 with val_loss=0.1157
#  Best weights updated at epoch 296 with val_loss=0.1157
#  Best weights updated at epoch 297 with val_loss=0.1157
#  Best weights updated at epoch 298 with val_loss=0.1156
#  Best weights updated at epoch 299 with val_loss=0.1156
#  Best weights updated at epoch 300 with val_loss=0.1156
#  Best weights updated at epoch 301 with val_loss=0.1156
#  Best weights updated at epoch 302 with val_loss=0.1155
#  Best weights updated at epoch 303 with val_loss=0.1155
#  Best weights updated at epoch 304 with val_loss=0.1155
#  Best weights updated at epoch 305 with val_loss=0.1155
#  Best weights updated at epoch 306 with val_loss=0.1154
#  Best weights updated at epoch 307 with val_loss=0.1154
#  Best weights updated at epoch 308 with val_loss=0.1154
#  Best weights updated at epoch 309 with val_loss=0.1154
#  Best weights updated at epoch 310 with val_loss=0.1153
#  Best weights updated at epoch 311 with val_loss=0.1153
#  Best weights updated at epoch 312 with val_loss=0.1153
#  Best weights updated at epoch 313 with val_loss=0.1153
#  Best weights updated at epoch 314 with val_loss=0.1152
#  Best weights updated at epoch 315 with val_loss=0.1152
#  Best weights updated at epoch 316 with val_loss=0.1152
#  Best weights updated at epoch 317 with val_loss=0.1151
#  Best weights updated at epoch 318 with val_loss=0.1151
#  Best weights updated at epoch 319 with val_loss=0.1151
#  Best weights updated at epoch 320 with val_loss=0.1151
#  Best weights updated at epoch 321 with val_loss=0.1150
#  Best weights updated at epoch 322 with val_loss=0.1150
#  Best weights updated at epoch 323 with val_loss=0.1150
#  Best weights updated at epoch 324 with val_loss=0.1150
#  Best weights updated at epoch 325 with val_loss=0.1149
#  Best weights updated at epoch 326 with val_loss=0.1149
#  Best weights updated at epoch 327 with val_loss=0.1149
#  Best weights updated at epoch 328 with val_loss=0.1149
#  Best weights updated at epoch 329 with val_loss=0.1148
#  Best weights updated at epoch 330 with val_loss=0.1148
#  Best weights updated at epoch 331 with val_loss=0.1148
#  Best weights updated at epoch 332 with val_loss=0.1148
#  Best weights updated at epoch 333 with val_loss=0.1148
#  Best weights updated at epoch 334 with val_loss=0.1147
#  Best weights updated at epoch 335 with val_loss=0.1147
#  Best weights updated at epoch 336 with val_loss=0.1147
#  Best weights updated at epoch 337 with val_loss=0.1147
#  Best weights updated at epoch 338 with val_loss=0.1146
#  Best weights updated at epoch 339 with val_loss=0.1146
#  Best weights updated at epoch 340 with val_loss=0.1146
#  Best weights updated at epoch 341 with val_loss=0.1145
#  Best weights updated at epoch 342 with val_loss=0.1145
#  Best weights updated at epoch 343 with val_loss=0.1145
#  Best weights updated at epoch 344 with val_loss=0.1145
#  Best weights updated at epoch 345 with val_loss=0.1144
#  Best weights updated at epoch 346 with val_loss=0.1144
#  Best weights updated at epoch 347 with val_loss=0.1144
#  Best weights updated at epoch 348 with val_loss=0.1143
#  Best weights updated at epoch 349 with val_loss=0.1143
#  Best weights updated at epoch 350 with val_loss=0.1143
#  Best weights updated at epoch 351 with val_loss=0.1142
#  Best weights updated at epoch 352 with val_loss=0.1142
#  Best weights updated at epoch 353 with val_loss=0.1142
#  Best weights updated at epoch 354 with val_loss=0.1141
#  Best weights updated at epoch 355 with val_loss=0.1141
#  Best weights updated at epoch 356 with val_loss=0.1140
#  Best weights updated at epoch 357 with val_loss=0.1140
#  Best weights updated at epoch 358 with val_loss=0.1140
#  Best weights updated at epoch 359 with val_loss=0.1139
#  Best weights updated at epoch 360 with val_loss=0.1139
#  Best weights updated at epoch 361 with val_loss=0.1138
#  Best weights updated at epoch 362 with val_loss=0.1138
#  Best weights updated at epoch 363 with val_loss=0.1137
#  Best weights updated at epoch 364 with val_loss=0.1137
#  Best weights updated at epoch 365 with val_loss=0.1136
#  Best weights updated at epoch 366 with val_loss=0.1136
#  Best weights updated at epoch 367 with val_loss=0.1135
#  Best weights updated at epoch 368 with val_loss=0.1135
#  Best weights updated at epoch 369 with val_loss=0.1134
#  Best weights updated at epoch 370 with val_loss=0.1133
#  Best weights updated at epoch 371 with val_loss=0.1133
#  Best weights updated at epoch 372 with val_loss=0.1132
#  Best weights updated at epoch 373 with val_loss=0.1132
#  Best weights updated at epoch 374 with val_loss=0.1131
#  Best weights updated at epoch 375 with val_loss=0.1130
#  Best weights updated at epoch 376 with val_loss=0.1130
#  Best weights updated at epoch 377 with val_loss=0.1129
#  Best weights updated at epoch 378 with val_loss=0.1128
#  Best weights updated at epoch 379 with val_loss=0.1127
#  Best weights updated at epoch 380 with val_loss=0.1127
#  Best weights updated at epoch 381 with val_loss=0.1126
#  Best weights updated at epoch 382 with val_loss=0.1125
#  Best weights updated at epoch 383 with val_loss=0.1124
#  Best weights updated at epoch 384 with val_loss=0.1124
#  Best weights updated at epoch 385 with val_loss=0.1123
#  Best weights updated at epoch 386 with val_loss=0.1122
#  Best weights updated at epoch 387 with val_loss=0.1121
#  Best weights updated at epoch 388 with val_loss=0.1120
#  Best weights updated at epoch 389 with val_loss=0.1120
#  Best weights updated at epoch 390 with val_loss=0.1119
#  Best weights updated at epoch 391 with val_loss=0.1118
#  Best weights updated at epoch 392 with val_loss=0.1117
#  Best weights updated at epoch 393 with val_loss=0.1116
#  Best weights updated at epoch 394 with val_loss=0.1115
#  Best weights updated at epoch 395 with val_loss=0.1114
#  Best weights updated at epoch 396 with val_loss=0.1113
#  Best weights updated at epoch 397 with val_loss=0.1113
#  Best weights updated at epoch 398 with val_loss=0.1112
#  Best weights updated at epoch 399 with val_loss=0.1111
#  Best weights updated at epoch 400 with val_loss=0.1110
#  Best weights updated at epoch 401 with val_loss=0.1109
#  Best weights updated at epoch 402 with val_loss=0.1108
#  Best weights updated at epoch 403 with val_loss=0.1107
#  Best weights updated at epoch 404 with val_loss=0.1106
#  Best weights updated at epoch 405 with val_loss=0.1105
#  Best weights updated at epoch 406 with val_loss=0.1104
#  Best weights updated at epoch 407 with val_loss=0.1103
#  Best weights updated at epoch 408 with val_loss=0.1103
#  Best weights updated at epoch 409 with val_loss=0.1102
#  Best weights updated at epoch 410 with val_loss=0.1101
#  Best weights updated at epoch 411 with val_loss=0.1100
#  Best weights updated at epoch 412 with val_loss=0.1099
#  Best weights updated at epoch 413 with val_loss=0.1098
#  Best weights updated at epoch 414 with val_loss=0.1097
#  Best weights updated at epoch 416 with val_loss=0.1096
#  Best weights updated at epoch 417 with val_loss=0.1096
#  Best weights updated at epoch 418 with val_loss=0.1095
#  Best weights updated at epoch 419 with val_loss=0.1092
#  Best weights updated at epoch 421 with val_loss=0.1090
#  Best weights updated at epoch 422 with val_loss=0.1090
#  Best weights updated at epoch 423 with val_loss=0.1090
#  Best weights updated at epoch 424 with val_loss=0.1087
#  Best weights updated at epoch 426 with val_loss=0.1085
#  Best weights updated at epoch 427 with val_loss=0.1084
#  Best weights updated at epoch 429 with val_loss=0.1081
#  Best weights updated at epoch 430 with val_loss=0.1081
#  Best weights updated at epoch 431 with val_loss=0.1080
#  Best weights updated at epoch 432 with val_loss=0.1078
#  Best weights updated at epoch 433 with val_loss=0.1077
#  Best weights updated at epoch 434 with val_loss=0.1075
#  Best weights updated at epoch 435 with val_loss=0.1073
#  Best weights updated at epoch 436 with val_loss=0.1073
#  Best weights updated at epoch 437 with val_loss=0.1069
#  Best weights updated at epoch 438 with val_loss=0.1069
#  Best weights updated at epoch 439 with val_loss=0.1065
#  Best weights updated at epoch 440 with val_loss=0.1064
#  Best weights updated at epoch 441 with val_loss=0.1061
#  Best weights updated at epoch 442 with val_loss=0.1059
#  Best weights updated at epoch 443 with val_loss=0.1056
#  Best weights updated at epoch 444 with val_loss=0.1055
#  Best weights updated at epoch 445 with val_loss=0.1050
#  Best weights updated at epoch 447 with val_loss=0.1047
#  Best weights updated at epoch 455 with val_loss=0.1031
#  Best weights updated at epoch 457 with val_loss=0.1031
#  Best weights updated at epoch 458 with val_loss=0.1021
#  Best weights updated at epoch 460 with val_loss=0.1003
#  Best weights updated at epoch 477 with val_loss=0.0997
#  Best weights updated at epoch 481 with val_loss=0.0971
#  Best weights updated at epoch 485 with val_loss=0.0960
#  Best weights updated at epoch 489 with val_loss=0.0952
#  Best weights updated at epoch 492 with val_loss=0.0929
#  Best weights updated at epoch 493 with val_loss=0.0919
#  Best weights updated at epoch 495 with val_loss=0.0911
#  Best weights updated at epoch 496 with val_loss=0.0907
#  Best weights updated at epoch 498 with val_loss=0.0901
#  Best weights updated at epoch 500 with val_loss=0.0882
#  Best weights updated at epoch 538 with val_loss=0.0868
#  Best weights updated at epoch 540 with val_loss=0.0851
#  Best weights updated at epoch 543 with val_loss=0.0840
#  Best weights updated at epoch 544 with val_loss=0.0829
#  Best weights updated at epoch 545 with val_loss=0.0822
#  Best weights updated at epoch 548 with val_loss=0.0802
#  Best weights updated at epoch 552 with val_loss=0.0798
#  Best weights updated at epoch 553 with val_loss=0.0788
#  Best weights updated at epoch 554 with val_loss=0.0777
#  Best weights updated at epoch 559 with val_loss=0.0776
#  Best weights updated at epoch 572 with val_loss=0.0776
#  Best weights updated at epoch 577 with val_loss=0.0775
#  Best weights updated at epoch 578 with val_loss=0.0775
#  Best weights updated at epoch 579 with val_loss=0.0775
#  Best weights updated at epoch 583 with val_loss=0.0775
#  Best weights updated at epoch 591 with val_loss=0.0774
#  Best weights updated at epoch 596 with val_loss=0.0774
#  Best weights updated at epoch 619 with val_loss=0.0772
# Restored best model from epoch after 100 with val_loss=0.0772
# 29/29 [==============================] - 1s 19ms/step
#  10%|█         | 1/10 [01:01<09:17, 61.99s/it]
#  Best weights updated at epoch 101 with val_loss=0.5734
#  Best weights updated at epoch 106 with val_loss=0.5732
#  Best weights updated at epoch 107 with val_loss=0.5729
#  Best weights updated at epoch 108 with val_loss=0.5726
#  Best weights updated at epoch 109 with val_loss=0.5721
#  Best weights updated at epoch 110 with val_loss=0.5716
#  Best weights updated at epoch 111 with val_loss=0.5711
#  Best weights updated at epoch 112 with val_loss=0.5706
#  Best weights updated at epoch 113 with val_loss=0.5701
#  Best weights updated at epoch 114 with val_loss=0.5696
#  Best weights updated at epoch 115 with val_loss=0.5691
#  Best weights updated at epoch 116 with val_loss=0.5686
#  Best weights updated at epoch 117 with val_loss=0.5681
#  Best weights updated at epoch 118 with val_loss=0.5675
#  Best weights updated at epoch 119 with val_loss=0.5669
#  Best weights updated at epoch 120 with val_loss=0.5664
#  Best weights updated at epoch 121 with val_loss=0.5659
#  Best weights updated at epoch 122 with val_loss=0.5655
#  Best weights updated at epoch 123 with val_loss=0.5650
#  Best weights updated at epoch 124 with val_loss=0.5646
#  Best weights updated at epoch 125 with val_loss=0.5642
#  Best weights updated at epoch 126 with val_loss=0.5638
#  Best weights updated at epoch 127 with val_loss=0.5633
#  Best weights updated at epoch 128 with val_loss=0.5628
#  Best weights updated at epoch 129 with val_loss=0.5623
#  Best weights updated at epoch 130 with val_loss=0.5618
#  Best weights updated at epoch 131 with val_loss=0.5613
#  Best weights updated at epoch 132 with val_loss=0.5608
#  Best weights updated at epoch 133 with val_loss=0.5603
#  Best weights updated at epoch 134 with val_loss=0.5598
#  Best weights updated at epoch 135 with val_loss=0.5592
#  Best weights updated at epoch 136 with val_loss=0.5586
#  Best weights updated at epoch 137 with val_loss=0.5580
#  Best weights updated at epoch 138 with val_loss=0.5573
#  Best weights updated at epoch 139 with val_loss=0.5566
#  Best weights updated at epoch 140 with val_loss=0.5558
#  Best weights updated at epoch 141 with val_loss=0.5550
#  Best weights updated at epoch 142 with val_loss=0.5542
#  Best weights updated at epoch 143 with val_loss=0.5532
#  Best weights updated at epoch 144 with val_loss=0.5522
#  Best weights updated at epoch 145 with val_loss=0.5511
#  Best weights updated at epoch 146 with val_loss=0.5499
#  Best weights updated at epoch 147 with val_loss=0.5486
#  Best weights updated at epoch 148 with val_loss=0.5472
#  Best weights updated at epoch 149 with val_loss=0.5458
#  Best weights updated at epoch 150 with val_loss=0.5442
#  Best weights updated at epoch 151 with val_loss=0.5425
#  Best weights updated at epoch 152 with val_loss=0.5407
#  Best weights updated at epoch 153 with val_loss=0.5388
#  Best weights updated at epoch 154 with val_loss=0.5367
#  Best weights updated at epoch 155 with val_loss=0.5345
#  Best weights updated at epoch 156 with val_loss=0.5321
#  Best weights updated at epoch 157 with val_loss=0.5295
#  Best weights updated at epoch 158 with val_loss=0.5267
#  Best weights updated at epoch 159 with val_loss=0.5235
#  Best weights updated at epoch 160 with val_loss=0.5201
#  Best weights updated at epoch 161 with val_loss=0.5164
#  Best weights updated at epoch 162 with val_loss=0.5123
#  Best weights updated at epoch 163 with val_loss=0.5078
#  Best weights updated at epoch 164 with val_loss=0.5028
#  Best weights updated at epoch 165 with val_loss=0.4972
#  Best weights updated at epoch 166 with val_loss=0.4909
#  Best weights updated at epoch 167 with val_loss=0.4840
#  Best weights updated at epoch 168 with val_loss=0.4761
#  Best weights updated at epoch 169 with val_loss=0.4673
#  Best weights updated at epoch 170 with val_loss=0.4572
#  Best weights updated at epoch 171 with val_loss=0.4459
#  Best weights updated at epoch 172 with val_loss=0.4331
#  Best weights updated at epoch 173 with val_loss=0.4185
#  Best weights updated at epoch 174 with val_loss=0.4019
#  Best weights updated at epoch 175 with val_loss=0.3831
#  Best weights updated at epoch 176 with val_loss=0.3618
#  Best weights updated at epoch 177 with val_loss=0.3379
#  Best weights updated at epoch 178 with val_loss=0.3114
#  Best weights updated at epoch 179 with val_loss=0.2825
#  Best weights updated at epoch 180 with val_loss=0.2517
#  Best weights updated at epoch 181 with val_loss=0.2214
#  Best weights updated at epoch 182 with val_loss=0.2017
#  Best weights updated at epoch 188 with val_loss=0.1739
#  Best weights updated at epoch 190 with val_loss=0.1635
#  Best weights updated at epoch 195 with val_loss=0.1506
#  Best weights updated at epoch 203 with val_loss=0.1460
#  Best weights updated at epoch 206 with val_loss=0.1435
#  Best weights updated at epoch 209 with val_loss=0.1418
#  Best weights updated at epoch 211 with val_loss=0.1409
#  Best weights updated at epoch 214 with val_loss=0.1389
#  Best weights updated at epoch 217 with val_loss=0.1374
#  Best weights updated at epoch 220 with val_loss=0.1357
#  Best weights updated at epoch 222 with val_loss=0.1347
#  Best weights updated at epoch 225 with val_loss=0.1339
#  Best weights updated at epoch 227 with val_loss=0.1339
#  Best weights updated at epoch 228 with val_loss=0.1339
#  Best weights updated at epoch 230 with val_loss=0.1335
#  Best weights updated at epoch 231 with val_loss=0.1327
#  Best weights updated at epoch 232 with val_loss=0.1326
#  Best weights updated at epoch 233 with val_loss=0.1317
#  Best weights updated at epoch 236 with val_loss=0.1306
#  Best weights updated at epoch 237 with val_loss=0.1304
#  Best weights updated at epoch 238 with val_loss=0.1299
#  Best weights updated at epoch 239 with val_loss=0.1299
#  Best weights updated at epoch 241 with val_loss=0.1291
#  Best weights updated at epoch 242 with val_loss=0.1286
#  Best weights updated at epoch 243 with val_loss=0.1283
#  Best weights updated at epoch 244 with val_loss=0.1280
#  Best weights updated at epoch 246 with val_loss=0.1278
#  Best weights updated at epoch 247 with val_loss=0.1271
#  Best weights updated at epoch 248 with val_loss=0.1268
#  Best weights updated at epoch 249 with val_loss=0.1264
#  Best weights updated at epoch 250 with val_loss=0.1263
#  Best weights updated at epoch 251 with val_loss=0.1260
#  Best weights updated at epoch 252 with val_loss=0.1254
#  Best weights updated at epoch 253 with val_loss=0.1251
#  Best weights updated at epoch 254 with val_loss=0.1248
#  Best weights updated at epoch 255 with val_loss=0.1245
#  Best weights updated at epoch 256 with val_loss=0.1243
#  Best weights updated at epoch 257 with val_loss=0.1238
#  Best weights updated at epoch 258 with val_loss=0.1233
#  Best weights updated at epoch 259 with val_loss=0.1230
#  Best weights updated at epoch 260 with val_loss=0.1226
#  Best weights updated at epoch 261 with val_loss=0.1224
#  Best weights updated at epoch 262 with val_loss=0.1221
#  Best weights updated at epoch 263 with val_loss=0.1217
#  Best weights updated at epoch 264 with val_loss=0.1214
#  Best weights updated at epoch 265 with val_loss=0.1211
#  Best weights updated at epoch 266 with val_loss=0.1208
#  Best weights updated at epoch 267 with val_loss=0.1205
#  Best weights updated at epoch 268 with val_loss=0.1202
#  Best weights updated at epoch 269 with val_loss=0.1199
#  Best weights updated at epoch 270 with val_loss=0.1196
#  Best weights updated at epoch 271 with val_loss=0.1193
#  Best weights updated at epoch 272 with val_loss=0.1190
#  Best weights updated at epoch 273 with val_loss=0.1187
#  Best weights updated at epoch 274 with val_loss=0.1184
#  Best weights updated at epoch 275 with val_loss=0.1182
#  Best weights updated at epoch 276 with val_loss=0.1178
#  Best weights updated at epoch 277 with val_loss=0.1175
#  Best weights updated at epoch 278 with val_loss=0.1172
#  Best weights updated at epoch 279 with val_loss=0.1169
#  Best weights updated at epoch 280 with val_loss=0.1166
#  Best weights updated at epoch 281 with val_loss=0.1163
#  Best weights updated at epoch 282 with val_loss=0.1160
#  Best weights updated at epoch 283 with val_loss=0.1157
#  Best weights updated at epoch 284 with val_loss=0.1154
#  Best weights updated at epoch 285 with val_loss=0.1151
#  Best weights updated at epoch 286 with val_loss=0.1148
#  Best weights updated at epoch 287 with val_loss=0.1145
#  Best weights updated at epoch 288 with val_loss=0.1142
#  Best weights updated at epoch 289 with val_loss=0.1140
#  Best weights updated at epoch 290 with val_loss=0.1137
#  Best weights updated at epoch 291 with val_loss=0.1135
#  Best weights updated at epoch 292 with val_loss=0.1132
#  Best weights updated at epoch 293 with val_loss=0.1129
#  Best weights updated at epoch 294 with val_loss=0.1127
#  Best weights updated at epoch 295 with val_loss=0.1125
#  Best weights updated at epoch 296 with val_loss=0.1123
#  Best weights updated at epoch 297 with val_loss=0.1121
#  Best weights updated at epoch 298 with val_loss=0.1119
#  Best weights updated at epoch 299 with val_loss=0.1117
#  Best weights updated at epoch 300 with val_loss=0.1116
#  Best weights updated at epoch 301 with val_loss=0.1114
#  Best weights updated at epoch 302 with val_loss=0.1112
#  Best weights updated at epoch 303 with val_loss=0.1110
#  Best weights updated at epoch 304 with val_loss=0.1109
#  Best weights updated at epoch 305 with val_loss=0.1108
#  Best weights updated at epoch 306 with val_loss=0.1106
#  Best weights updated at epoch 307 with val_loss=0.1104
#  Best weights updated at epoch 308 with val_loss=0.1103
#  Best weights updated at epoch 309 with val_loss=0.1102
#  Best weights updated at epoch 310 with val_loss=0.1100
#  Best weights updated at epoch 311 with val_loss=0.1099
#  Best weights updated at epoch 312 with val_loss=0.1098
#  Best weights updated at epoch 313 with val_loss=0.1096
#  Best weights updated at epoch 314 with val_loss=0.1095
#  Best weights updated at epoch 315 with val_loss=0.1094
#  Best weights updated at epoch 316 with val_loss=0.1093
#  Best weights updated at epoch 317 with val_loss=0.1091
#  Best weights updated at epoch 318 with val_loss=0.1090
#  Best weights updated at epoch 319 with val_loss=0.1089
#  Best weights updated at epoch 320 with val_loss=0.1088
#  Best weights updated at epoch 321 with val_loss=0.1086
#  Best weights updated at epoch 322 with val_loss=0.1085
#  Best weights updated at epoch 323 with val_loss=0.1084
#  Best weights updated at epoch 324 with val_loss=0.1083
#  Best weights updated at epoch 325 with val_loss=0.1081
#  Best weights updated at epoch 326 with val_loss=0.1080
#  Best weights updated at epoch 327 with val_loss=0.1079
#  Best weights updated at epoch 328 with val_loss=0.1078
#  Best weights updated at epoch 329 with val_loss=0.1077
#  Best weights updated at epoch 330 with val_loss=0.1076
#  Best weights updated at epoch 331 with val_loss=0.1075
#  Best weights updated at epoch 332 with val_loss=0.1074
#  Best weights updated at epoch 333 with val_loss=0.1073
#  Best weights updated at epoch 334 with val_loss=0.1072
#  Best weights updated at epoch 335 with val_loss=0.1071
#  Best weights updated at epoch 336 with val_loss=0.1070
#  Best weights updated at epoch 337 with val_loss=0.1069
#  Best weights updated at epoch 338 with val_loss=0.1068
#  Best weights updated at epoch 339 with val_loss=0.1068
#  Best weights updated at epoch 340 with val_loss=0.1067
#  Best weights updated at epoch 341 with val_loss=0.1066
#  Best weights updated at epoch 342 with val_loss=0.1065
#  Best weights updated at epoch 343 with val_loss=0.1065
#  Best weights updated at epoch 344 with val_loss=0.1064
#  Best weights updated at epoch 345 with val_loss=0.1063
#  Best weights updated at epoch 346 with val_loss=0.1063
#  Best weights updated at epoch 347 with val_loss=0.1062
#  Best weights updated at epoch 348 with val_loss=0.1061
#  Best weights updated at epoch 349 with val_loss=0.1061
#  Best weights updated at epoch 350 with val_loss=0.1060
#  Best weights updated at epoch 351 with val_loss=0.1060
#  Best weights updated at epoch 352 with val_loss=0.1059
#  Best weights updated at epoch 353 with val_loss=0.1059
#  Best weights updated at epoch 354 with val_loss=0.1058
#  Best weights updated at epoch 355 with val_loss=0.1058
#  Best weights updated at epoch 356 with val_loss=0.1057
#  Best weights updated at epoch 357 with val_loss=0.1056
#  Best weights updated at epoch 358 with val_loss=0.1056
#  Best weights updated at epoch 359 with val_loss=0.1055
#  Best weights updated at epoch 360 with val_loss=0.1055
#  Best weights updated at epoch 361 with val_loss=0.1054
#  Best weights updated at epoch 362 with val_loss=0.1054
#  Best weights updated at epoch 363 with val_loss=0.1053
#  Best weights updated at epoch 364 with val_loss=0.1053
#  Best weights updated at epoch 365 with val_loss=0.1052
#  Best weights updated at epoch 366 with val_loss=0.1052
#  Best weights updated at epoch 367 with val_loss=0.1051
#  Best weights updated at epoch 368 with val_loss=0.1051
#  Best weights updated at epoch 369 with val_loss=0.1050
#  Best weights updated at epoch 370 with val_loss=0.1050
#  Best weights updated at epoch 371 with val_loss=0.1049
#  Best weights updated at epoch 372 with val_loss=0.1049
#  Best weights updated at epoch 373 with val_loss=0.1048
#  Best weights updated at epoch 374 with val_loss=0.1048
#  Best weights updated at epoch 375 with val_loss=0.1047
#  Best weights updated at epoch 376 with val_loss=0.1047
#  Best weights updated at epoch 377 with val_loss=0.1046
#  Best weights updated at epoch 378 with val_loss=0.1046
#  Best weights updated at epoch 379 with val_loss=0.1045
#  Best weights updated at epoch 380 with val_loss=0.1045
#  Best weights updated at epoch 381 with val_loss=0.1044
#  Best weights updated at epoch 382 with val_loss=0.1044
#  Best weights updated at epoch 383 with val_loss=0.1043
#  Best weights updated at epoch 384 with val_loss=0.1043
#  Best weights updated at epoch 385 with val_loss=0.1042
#  Best weights updated at epoch 386 with val_loss=0.1042
#  Best weights updated at epoch 387 with val_loss=0.1041
#  Best weights updated at epoch 388 with val_loss=0.1041
#  Best weights updated at epoch 389 with val_loss=0.1040
#  Best weights updated at epoch 390 with val_loss=0.1040
#  Best weights updated at epoch 391 with val_loss=0.1039
#  Best weights updated at epoch 392 with val_loss=0.1039
#  Best weights updated at epoch 393 with val_loss=0.1038
#  Best weights updated at epoch 394 with val_loss=0.1038
#  Best weights updated at epoch 395 with val_loss=0.1037
#  Best weights updated at epoch 396 with val_loss=0.1037
#  Best weights updated at epoch 397 with val_loss=0.1036
#  Best weights updated at epoch 398 with val_loss=0.1036
#  Best weights updated at epoch 399 with val_loss=0.1036
#  Best weights updated at epoch 400 with val_loss=0.1035
#  Best weights updated at epoch 401 with val_loss=0.1035
#  Best weights updated at epoch 402 with val_loss=0.1034
#  Best weights updated at epoch 403 with val_loss=0.1034
#  Best weights updated at epoch 404 with val_loss=0.1034
#  Best weights updated at epoch 405 with val_loss=0.1033
#  Best weights updated at epoch 406 with val_loss=0.1033
#  Best weights updated at epoch 407 with val_loss=0.1032
#  Best weights updated at epoch 408 with val_loss=0.1032
#  Best weights updated at epoch 409 with val_loss=0.1032
#  Best weights updated at epoch 410 with val_loss=0.1031
#  Best weights updated at epoch 411 with val_loss=0.1031
#  Best weights updated at epoch 412 with val_loss=0.1031
#  Best weights updated at epoch 413 with val_loss=0.1030
#  Best weights updated at epoch 414 with val_loss=0.1030
#  Best weights updated at epoch 415 with val_loss=0.1029
#  Best weights updated at epoch 416 with val_loss=0.1029
#  Best weights updated at epoch 417 with val_loss=0.1029
#  Best weights updated at epoch 418 with val_loss=0.1028
#  Best weights updated at epoch 419 with val_loss=0.1028
#  Best weights updated at epoch 420 with val_loss=0.1028
#  Best weights updated at epoch 421 with val_loss=0.1027
#  Best weights updated at epoch 422 with val_loss=0.1027
#  Best weights updated at epoch 423 with val_loss=0.1027
#  Best weights updated at epoch 424 with val_loss=0.1026
#  Best weights updated at epoch 425 with val_loss=0.1026
#  Best weights updated at epoch 426 with val_loss=0.1026
#  Best weights updated at epoch 427 with val_loss=0.1025
#  Best weights updated at epoch 428 with val_loss=0.1025
#  Best weights updated at epoch 429 with val_loss=0.1025
#  Best weights updated at epoch 430 with val_loss=0.1024
#  Best weights updated at epoch 431 with val_loss=0.1024
#  Best weights updated at epoch 432 with val_loss=0.1024
#  Best weights updated at epoch 433 with val_loss=0.1023
#  Best weights updated at epoch 434 with val_loss=0.1023
#  Best weights updated at epoch 435 with val_loss=0.1023
#  Best weights updated at epoch 436 with val_loss=0.1022
#  Best weights updated at epoch 437 with val_loss=0.1022
#  Best weights updated at epoch 438 with val_loss=0.1022
#  Best weights updated at epoch 439 with val_loss=0.1021
#  Best weights updated at epoch 440 with val_loss=0.1021
#  Best weights updated at epoch 441 with val_loss=0.1021
#  Best weights updated at epoch 442 with val_loss=0.1020
#  Best weights updated at epoch 443 with val_loss=0.1020
#  Best weights updated at epoch 444 with val_loss=0.1020
#  Best weights updated at epoch 445 with val_loss=0.1019
#  Best weights updated at epoch 446 with val_loss=0.1019
#  Best weights updated at epoch 447 with val_loss=0.1019
#  Best weights updated at epoch 448 with val_loss=0.1018
#  Best weights updated at epoch 449 with val_loss=0.1018
#  Best weights updated at epoch 450 with val_loss=0.1018
#  Best weights updated at epoch 451 with val_loss=0.1017
#  Best weights updated at epoch 452 with val_loss=0.1017
#  Best weights updated at epoch 453 with val_loss=0.1017
#  Best weights updated at epoch 454 with val_loss=0.1016
#  Best weights updated at epoch 455 with val_loss=0.1016
#  Best weights updated at epoch 456 with val_loss=0.1016
#  Best weights updated at epoch 457 with val_loss=0.1015
#  Best weights updated at epoch 458 with val_loss=0.1015
#  Best weights updated at epoch 459 with val_loss=0.1015
#  Best weights updated at epoch 460 with val_loss=0.1014
#  Best weights updated at epoch 461 with val_loss=0.1014
#  Best weights updated at epoch 462 with val_loss=0.1014
#  Best weights updated at epoch 463 with val_loss=0.1013
#  Best weights updated at epoch 464 with val_loss=0.1013
#  Best weights updated at epoch 465 with val_loss=0.1013
#  Best weights updated at epoch 466 with val_loss=0.1012
#  Best weights updated at epoch 467 with val_loss=0.1012
#  Best weights updated at epoch 468 with val_loss=0.1012
#  Best weights updated at epoch 469 with val_loss=0.1011
#  Best weights updated at epoch 470 with val_loss=0.1011
#  Best weights updated at epoch 471 with val_loss=0.1011
#  Best weights updated at epoch 472 with val_loss=0.1010
#  Best weights updated at epoch 473 with val_loss=0.1010
#  Best weights updated at epoch 474 with val_loss=0.1010
#  Best weights updated at epoch 475 with val_loss=0.1010
#  Best weights updated at epoch 476 with val_loss=0.1009
#  Best weights updated at epoch 477 with val_loss=0.1009
#  Best weights updated at epoch 478 with val_loss=0.1009
#  Best weights updated at epoch 479 with val_loss=0.1008
#  Best weights updated at epoch 480 with val_loss=0.1008
#  Best weights updated at epoch 481 with val_loss=0.1008
#  Best weights updated at epoch 482 with val_loss=0.1007
#  Best weights updated at epoch 483 with val_loss=0.1007
#  Best weights updated at epoch 484 with val_loss=0.1007
#  Best weights updated at epoch 485 with val_loss=0.1006
#  Best weights updated at epoch 486 with val_loss=0.1006
#  Best weights updated at epoch 487 with val_loss=0.1006
#  Best weights updated at epoch 488 with val_loss=0.1005
#  Best weights updated at epoch 489 with val_loss=0.1005
#  Best weights updated at epoch 490 with val_loss=0.1005
#  Best weights updated at epoch 491 with val_loss=0.1004
#  Best weights updated at epoch 492 with val_loss=0.1004
#  Best weights updated at epoch 493 with val_loss=0.1003
#  Best weights updated at epoch 494 with val_loss=0.1003
#  Best weights updated at epoch 495 with val_loss=0.1003
#  Best weights updated at epoch 496 with val_loss=0.1002
#  Best weights updated at epoch 497 with val_loss=0.1002
#  Best weights updated at epoch 498 with val_loss=0.1002
#  Best weights updated at epoch 499 with val_loss=0.1001
#  Best weights updated at epoch 500 with val_loss=0.1001
#  Best weights updated at epoch 501 with val_loss=0.1001
#  Best weights updated at epoch 502 with val_loss=0.1000
#  Best weights updated at epoch 503 with val_loss=0.1000
#  Best weights updated at epoch 504 with val_loss=0.0999
#  Best weights updated at epoch 505 with val_loss=0.0999
#  Best weights updated at epoch 506 with val_loss=0.0998
#  Best weights updated at epoch 507 with val_loss=0.0998
#  Best weights updated at epoch 508 with val_loss=0.0998
#  Best weights updated at epoch 509 with val_loss=0.0997
#  Best weights updated at epoch 510 with val_loss=0.0997
#  Best weights updated at epoch 511 with val_loss=0.0996
#  Best weights updated at epoch 512 with val_loss=0.0996
#  Best weights updated at epoch 513 with val_loss=0.0995
#  Best weights updated at epoch 514 with val_loss=0.0995
#  Best weights updated at epoch 515 with val_loss=0.0994
#  Best weights updated at epoch 516 with val_loss=0.0994
#  Best weights updated at epoch 517 with val_loss=0.0993
#  Best weights updated at epoch 518 with val_loss=0.0993
#  Best weights updated at epoch 519 with val_loss=0.0992
#  Best weights updated at epoch 520 with val_loss=0.0991
#  Best weights updated at epoch 521 with val_loss=0.0991
#  Best weights updated at epoch 522 with val_loss=0.0990
#  Best weights updated at epoch 523 with val_loss=0.0989
#  Best weights updated at epoch 524 with val_loss=0.0989
#  Best weights updated at epoch 525 with val_loss=0.0988
#  Best weights updated at epoch 526 with val_loss=0.0987
#  Best weights updated at epoch 527 with val_loss=0.0986
#  Best weights updated at epoch 528 with val_loss=0.0985
#  Best weights updated at epoch 529 with val_loss=0.0985
#  Best weights updated at epoch 530 with val_loss=0.0984
#  Best weights updated at epoch 531 with val_loss=0.0983
#  Best weights updated at epoch 532 with val_loss=0.0982
#  Best weights updated at epoch 533 with val_loss=0.0981
#  Best weights updated at epoch 534 with val_loss=0.0979
#  Best weights updated at epoch 535 with val_loss=0.0978
#  Best weights updated at epoch 536 with val_loss=0.0977
#  Best weights updated at epoch 537 with val_loss=0.0976
#  Best weights updated at epoch 538 with val_loss=0.0974
#  Best weights updated at epoch 539 with val_loss=0.0973
#  Best weights updated at epoch 540 with val_loss=0.0971
#  Best weights updated at epoch 541 with val_loss=0.0970
#  Best weights updated at epoch 542 with val_loss=0.0968
#  Best weights updated at epoch 543 with val_loss=0.0966
#  Best weights updated at epoch 544 with val_loss=0.0964
#  Best weights updated at epoch 545 with val_loss=0.0962
#  Best weights updated at epoch 546 with val_loss=0.0961
#  Best weights updated at epoch 550 with val_loss=0.0954
#  Best weights updated at epoch 553 with val_loss=0.0949
#  Best weights updated at epoch 555 with val_loss=0.0949
#  Best weights updated at epoch 558 with val_loss=0.0943
#  Best weights updated at epoch 559 with val_loss=0.0942
#  Best weights updated at epoch 561 with val_loss=0.0940
#  Best weights updated at epoch 562 with val_loss=0.0934
#  Best weights updated at epoch 565 with val_loss=0.0933
#  Best weights updated at epoch 566 with val_loss=0.0924
#  Best weights updated at epoch 574 with val_loss=0.0907
#  Best weights updated at epoch 581 with val_loss=0.0897
#  Best weights updated at epoch 585 with val_loss=0.0891
#  Best weights updated at epoch 590 with val_loss=0.0888
#  Best weights updated at epoch 591 with val_loss=0.0880
#  Best weights updated at epoch 592 with val_loss=0.0875
#  Best weights updated at epoch 593 with val_loss=0.0875
#  Best weights updated at epoch 639 with val_loss=0.0874
#  Best weights updated at epoch 640 with val_loss=0.0867
#  Best weights updated at epoch 641 with val_loss=0.0865
#  Best weights updated at epoch 642 with val_loss=0.0865
#  Best weights updated at epoch 643 with val_loss=0.0862
#  Best weights updated at epoch 644 with val_loss=0.0855
#  Best weights updated at epoch 645 with val_loss=0.0848
#  Best weights updated at epoch 646 with val_loss=0.0838
#  Best weights updated at epoch 647 with val_loss=0.0828
#  Best weights updated at epoch 648 with val_loss=0.0822
#  Best weights updated at epoch 649 with val_loss=0.0821
#  Best weights updated at epoch 651 with val_loss=0.0820
#  Best weights updated at epoch 652 with val_loss=0.0808
#  Best weights updated at epoch 653 with val_loss=0.0799
#  Best weights updated at epoch 654 with val_loss=0.0795
#  Best weights updated at epoch 655 with val_loss=0.0789
#  Best weights updated at epoch 656 with val_loss=0.0788
#  Best weights updated at epoch 657 with val_loss=0.0788
#  Best weights updated at epoch 658 with val_loss=0.0779
#  Best weights updated at epoch 659 with val_loss=0.0774
#  Best weights updated at epoch 660 with val_loss=0.0768
#  Best weights updated at epoch 661 with val_loss=0.0759
#  Best weights updated at epoch 662 with val_loss=0.0758
#  Best weights updated at epoch 663 with val_loss=0.0750
#  Best weights updated at epoch 665 with val_loss=0.0745
#  Best weights updated at epoch 793 with val_loss=0.0745
#  Best weights updated at epoch 794 with val_loss=0.0742
#  Best weights updated at epoch 795 with val_loss=0.0740
#  Best weights updated at epoch 796 with val_loss=0.0737
#  Best weights updated at epoch 797 with val_loss=0.0734
#  Best weights updated at epoch 798 with val_loss=0.0732
#  Best weights updated at epoch 799 with val_loss=0.0730
#  Best weights updated at epoch 800 with val_loss=0.0728
#  Best weights updated at epoch 801 with val_loss=0.0727
#  Best weights updated at epoch 802 with val_loss=0.0725
#  Best weights updated at epoch 803 with val_loss=0.0723
#  Best weights updated at epoch 804 with val_loss=0.0722
#  Best weights updated at epoch 805 with val_loss=0.0721
#  Best weights updated at epoch 806 with val_loss=0.0720
#  Best weights updated at epoch 807 with val_loss=0.0719
#  Best weights updated at epoch 808 with val_loss=0.0718
#  Best weights updated at epoch 809 with val_loss=0.0717
#  Best weights updated at epoch 810 with val_loss=0.0716
#  Best weights updated at epoch 811 with val_loss=0.0715
#  Best weights updated at epoch 812 with val_loss=0.0715
#  Best weights updated at epoch 813 with val_loss=0.0714
#  Best weights updated at epoch 814 with val_loss=0.0714
#  Best weights updated at epoch 815 with val_loss=0.0713
#  Best weights updated at epoch 816 with val_loss=0.0713
#  Best weights updated at epoch 817 with val_loss=0.0712
#  Best weights updated at epoch 818 with val_loss=0.0712
#  Best weights updated at epoch 819 with val_loss=0.0711
#  Best weights updated at epoch 820 with val_loss=0.0711
#  Best weights updated at epoch 821 with val_loss=0.0710
#  Best weights updated at epoch 822 with val_loss=0.0710
#  Best weights updated at epoch 823 with val_loss=0.0710
#  Best weights updated at epoch 824 with val_loss=0.0709
#  Best weights updated at epoch 825 with val_loss=0.0709
#  Best weights updated at epoch 826 with val_loss=0.0709
#  Best weights updated at epoch 827 with val_loss=0.0709
#  Best weights updated at epoch 828 with val_loss=0.0708
#  Best weights updated at epoch 829 with val_loss=0.0708
#  Best weights updated at epoch 830 with val_loss=0.0708
#  Best weights updated at epoch 831 with val_loss=0.0707
#  Best weights updated at epoch 832 with val_loss=0.0707
#  Best weights updated at epoch 833 with val_loss=0.0707
#  Best weights updated at epoch 834 with val_loss=0.0707
#  Best weights updated at epoch 835 with val_loss=0.0706
#  Best weights updated at epoch 836 with val_loss=0.0706
#  Best weights updated at epoch 837 with val_loss=0.0706
#  Best weights updated at epoch 838 with val_loss=0.0706
#  Best weights updated at epoch 839 with val_loss=0.0705
#  Best weights updated at epoch 840 with val_loss=0.0705
#  Best weights updated at epoch 841 with val_loss=0.0705
#  Best weights updated at epoch 842 with val_loss=0.0705
#  Best weights updated at epoch 843 with val_loss=0.0704
#  Best weights updated at epoch 844 with val_loss=0.0704
#  Best weights updated at epoch 845 with val_loss=0.0704
#  Best weights updated at epoch 846 with val_loss=0.0704
#  Best weights updated at epoch 847 with val_loss=0.0703
#  Best weights updated at epoch 848 with val_loss=0.0703
#  Best weights updated at epoch 849 with val_loss=0.0703
#  Best weights updated at epoch 850 with val_loss=0.0703
#  Best weights updated at epoch 851 with val_loss=0.0702
# ...
#  Best weights updated at epoch 539 with val_loss=0.0169
#  Best weights updated at epoch 552 with val_loss=0.0169
#  Best weights updated at epoch 553 with val_loss=0.0167
#  Best weights updated at epoch 555 with val_loss=0.0165
#  Best weights updated at epoch 559 with val_loss=0.0165
#  Best weights updated at epoch 561 with val_loss=0.0165
#  Best weights updated at epoch 562 with val_loss=0.0164
#  Best weights updated at epoch 567 with val_loss=0.0164
#  Best weights updated at epoch 570 with val_loss=0.0164
#  Best weights updated at epoch 572 with val_loss=0.0164
#  Best weights updated at epoch 579 with val_loss=0.0163
#  Best weights updated at epoch 581 with val_loss=0.0163
#  Best weights updated at epoch 582 with val_loss=0.0163
#  Best weights updated at epoch 587 with val_loss=0.0163
#  Best weights updated at epoch 588 with val_loss=0.0163
#  Best weights updated at epoch 596 with val_loss=0.0163
#  Best weights updated at epoch 599 with val_loss=0.0162
#  Best weights updated at epoch 643 with val_loss=0.0161
#  Best weights updated at epoch 646 with val_loss=0.0161
#  Best weights updated at epoch 651 with val_loss=0.0161
#  Best weights updated at epoch 655 with val_loss=0.0160
#  Best weights updated at epoch 659 with val_loss=0.0160
#  Best weights updated at epoch 660 with val_loss=0.0160
#  Best weights updated at epoch 663 with val_loss=0.0160
#  Best weights updated at epoch 664 with val_loss=0.0160
#  Best weights updated at epoch 665 with val_loss=0.0160
#  Best weights updated at epoch 674 with val_loss=0.0160
#  Best weights updated at epoch 675 with val_loss=0.0160
#  Best weights updated at epoch 677 with val_loss=0.0160
#  Best weights updated at epoch 704 with val_loss=0.0160
#  Best weights updated at epoch 710 with val_loss=0.0160
#  Best weights updated at epoch 714 with val_loss=0.0159
#  Best weights updated at epoch 719 with val_loss=0.0159
#  Best weights updated at epoch 727 with val_loss=0.0159
#  Best weights updated at epoch 728 with val_loss=0.0159
#  Best weights updated at epoch 734 with val_loss=0.0159
#  Best weights updated at epoch 752 with val_loss=0.0159
#  Best weights updated at epoch 798 with val_loss=0.0159
#  Best weights updated at epoch 800 with val_loss=0.0158
#  Best weights updated at epoch 815 with val_loss=0.0158
#  Best weights updated at epoch 816 with val_loss=0.0158
#  Best weights updated at epoch 847 with val_loss=0.0158
#  Best weights updated at epoch 887 with val_loss=0.0157
#  Best weights updated at epoch 888 with val_loss=0.0157
#  Best weights updated at epoch 889 with val_loss=0.0157
#  Best weights updated at epoch 890 with val_loss=0.0157
#  Best weights updated at epoch 950 with val_loss=0.0156
#  Best weights updated at epoch 953 with val_loss=0.0156
#  Best weights updated at epoch 955 with val_loss=0.0156
#  Best weights updated at epoch 956 with val_loss=0.0156
#  Best weights updated at epoch 958 with val_loss=0.0156
#  Best weights updated at epoch 960 with val_loss=0.0156
#  Best weights updated at epoch 962 with val_loss=0.0155
#  Best weights updated at epoch 989 with val_loss=0.0155
#  Best weights updated at epoch 993 with val_loss=0.0155
# Restored best model from epoch after 100 with val_loss=0.0155
# 29/29 [==============================] - 3s 74ms/step
#  90%|█████████ | 9/10 [22:55<02:34, 154.69s/it]
#  Best weights updated at epoch 101 with val_loss=0.0600
#  Best weights updated at epoch 103 with val_loss=0.0599
#  Best weights updated at epoch 104 with val_loss=0.0599
#  Best weights updated at epoch 105 with val_loss=0.0597
#  Best weights updated at epoch 106 with val_loss=0.0595
#  Best weights updated at epoch 111 with val_loss=0.0593
#  Best weights updated at epoch 113 with val_loss=0.0592
#  Best weights updated at epoch 114 with val_loss=0.0591
#  Best weights updated at epoch 115 with val_loss=0.0591
#  Best weights updated at epoch 116 with val_loss=0.0590
#  Best weights updated at epoch 117 with val_loss=0.0590
#  Best weights updated at epoch 119 with val_loss=0.0589
#  Best weights updated at epoch 120 with val_loss=0.0589
#  Best weights updated at epoch 121 with val_loss=0.0589
#  Best weights updated at epoch 122 with val_loss=0.0588
#  Best weights updated at epoch 125 with val_loss=0.0587
#  Best weights updated at epoch 127 with val_loss=0.0586
#  Best weights updated at epoch 130 with val_loss=0.0585
#  Best weights updated at epoch 131 with val_loss=0.0585
#  Best weights updated at epoch 139 with val_loss=0.0583
#  Best weights updated at epoch 140 with val_loss=0.0580
#  Best weights updated at epoch 142 with val_loss=0.0580
#  Best weights updated at epoch 144 with val_loss=0.0579
#  Best weights updated at epoch 146 with val_loss=0.0578
#  Best weights updated at epoch 148 with val_loss=0.0577
#  Best weights updated at epoch 151 with val_loss=0.0577
#  Best weights updated at epoch 152 with val_loss=0.0577
#  Best weights updated at epoch 157 with val_loss=0.0576
#  Best weights updated at epoch 158 with val_loss=0.0574
#  Best weights updated at epoch 160 with val_loss=0.0572
#  Best weights updated at epoch 165 with val_loss=0.0571
#  Best weights updated at epoch 166 with val_loss=0.0569
#  Best weights updated at epoch 167 with val_loss=0.0569
#  Best weights updated at epoch 169 with val_loss=0.0569
#  Best weights updated at epoch 170 with val_loss=0.0568
#  Best weights updated at epoch 171 with val_loss=0.0566
#  Best weights updated at epoch 175 with val_loss=0.0563
#  Best weights updated at epoch 176 with val_loss=0.0562
#  Best weights updated at epoch 178 with val_loss=0.0561
#  Best weights updated at epoch 179 with val_loss=0.0559
#  Best weights updated at epoch 181 with val_loss=0.0557
#  Best weights updated at epoch 183 with val_loss=0.0553
#  Best weights updated at epoch 199 with val_loss=0.0549
#  Best weights updated at epoch 201 with val_loss=0.0527
#  Best weights updated at epoch 202 with val_loss=0.0506
#  Best weights updated at epoch 205 with val_loss=0.0480
#  Best weights updated at epoch 206 with val_loss=0.0458
#  Best weights updated at epoch 207 with val_loss=0.0445
#  Best weights updated at epoch 208 with val_loss=0.0424
#  Best weights updated at epoch 264 with val_loss=0.0417
#  Best weights updated at epoch 265 with val_loss=0.0405
#  Best weights updated at epoch 266 with val_loss=0.0392
#  Best weights updated at epoch 267 with val_loss=0.0378
#  Best weights updated at epoch 268 with val_loss=0.0363
#  Best weights updated at epoch 269 with val_loss=0.0347
#  Best weights updated at epoch 270 with val_loss=0.0330
#  Best weights updated at epoch 271 with val_loss=0.0315
#  Best weights updated at epoch 272 with val_loss=0.0297
#  Best weights updated at epoch 273 with val_loss=0.0285
#  Best weights updated at epoch 274 with val_loss=0.0271
#  Best weights updated at epoch 275 with val_loss=0.0258
#  Best weights updated at epoch 287 with val_loss=0.0249
#  Best weights updated at epoch 288 with val_loss=0.0230
#  Best weights updated at epoch 289 with val_loss=0.0224
#  Best weights updated at epoch 290 with val_loss=0.0218
#  Best weights updated at epoch 292 with val_loss=0.0213
#  Best weights updated at epoch 293 with val_loss=0.0211
#  Best weights updated at epoch 295 with val_loss=0.0208
#  Best weights updated at epoch 296 with val_loss=0.0207
#  Best weights updated at epoch 297 with val_loss=0.0206
#  Best weights updated at epoch 298 with val_loss=0.0205
#  Best weights updated at epoch 299 with val_loss=0.0204
#  Best weights updated at epoch 301 with val_loss=0.0202
#  Best weights updated at epoch 302 with val_loss=0.0202
#  Best weights updated at epoch 303 with val_loss=0.0201
#  Best weights updated at epoch 304 with val_loss=0.0200
#  Best weights updated at epoch 305 with val_loss=0.0199
#  Best weights updated at epoch 306 with val_loss=0.0198
#  Best weights updated at epoch 309 with val_loss=0.0196
#  Best weights updated at epoch 310 with val_loss=0.0195
#  Best weights updated at epoch 312 with val_loss=0.0193
#  Best weights updated at epoch 314 with val_loss=0.0192
#  Best weights updated at epoch 315 with val_loss=0.0190
#  Best weights updated at epoch 317 with val_loss=0.0189
#  Best weights updated at epoch 318 with val_loss=0.0188
#  Best weights updated at epoch 319 with val_loss=0.0187
#  Best weights updated at epoch 320 with val_loss=0.0187
#  Best weights updated at epoch 321 with val_loss=0.0186
#  Best weights updated at epoch 322 with val_loss=0.0186
#  Best weights updated at epoch 323 with val_loss=0.0185
#  Best weights updated at epoch 324 with val_loss=0.0184
#  Best weights updated at epoch 325 with val_loss=0.0182
#  Best weights updated at epoch 329 with val_loss=0.0181
#  Best weights updated at epoch 330 with val_loss=0.0179
#  Best weights updated at epoch 335 with val_loss=0.0179
#  Best weights updated at epoch 336 with val_loss=0.0175
#  Best weights updated at epoch 338 with val_loss=0.0175
#  Best weights updated at epoch 339 with val_loss=0.0174
#  Best weights updated at epoch 341 with val_loss=0.0173
#  Best weights updated at epoch 345 with val_loss=0.0173
#  Best weights updated at epoch 353 with val_loss=0.0171
#  Best weights updated at epoch 354 with val_loss=0.0170
#  Best weights updated at epoch 359 with val_loss=0.0169
#  Best weights updated at epoch 364 with val_loss=0.0168
#  Best weights updated at epoch 366 with val_loss=0.0168
#  Best weights updated at epoch 367 with val_loss=0.0167
#  Best weights updated at epoch 377 with val_loss=0.0166
#  Best weights updated at epoch 380 with val_loss=0.0165
#  Best weights updated at epoch 381 with val_loss=0.0165
#  Best weights updated at epoch 384 with val_loss=0.0165
#  Best weights updated at epoch 388 with val_loss=0.0165
#  Best weights updated at epoch 419 with val_loss=0.0164
#  Best weights updated at epoch 422 with val_loss=0.0164
#  Best weights updated at epoch 423 with val_loss=0.0163
#  Best weights updated at epoch 424 with val_loss=0.0162
#  Best weights updated at epoch 427 with val_loss=0.0162
#  Best weights updated at epoch 433 with val_loss=0.0162
#  Best weights updated at epoch 443 with val_loss=0.0162
#  Best weights updated at epoch 453 with val_loss=0.0162
#  Best weights updated at epoch 493 with val_loss=0.0161
#  Best weights updated at epoch 494 with val_loss=0.0161
#  Best weights updated at epoch 495 with val_loss=0.0160
#  Best weights updated at epoch 496 with val_loss=0.0160
#  Best weights updated at epoch 501 with val_loss=0.0160
#  Best weights updated at epoch 502 with val_loss=0.0159
#  Best weights updated at epoch 508 with val_loss=0.0159
#  Best weights updated at epoch 511 with val_loss=0.0159
#  Best weights updated at epoch 513 with val_loss=0.0159
#  Best weights updated at epoch 519 with val_loss=0.0159
#  Best weights updated at epoch 526 with val_loss=0.0158
#  Best weights updated at epoch 533 with val_loss=0.0158
#  Best weights updated at epoch 534 with val_loss=0.0158
#  Best weights updated at epoch 535 with val_loss=0.0158
#  Best weights updated at epoch 546 with val_loss=0.0158
#  Best weights updated at epoch 558 with val_loss=0.0158
#  Best weights updated at epoch 563 with val_loss=0.0158
#  Best weights updated at epoch 566 with val_loss=0.0158
#  Best weights updated at epoch 570 with val_loss=0.0158
#  Best weights updated at epoch 573 with val_loss=0.0158
#  Best weights updated at epoch 574 with val_loss=0.0157
#  Best weights updated at epoch 578 with val_loss=0.0157
#  Best weights updated at epoch 584 with val_loss=0.0157
#  Best weights updated at epoch 588 with val_loss=0.0157
#  Best weights updated at epoch 594 with val_loss=0.0157
#  Best weights updated at epoch 596 with val_loss=0.0157
#  Best weights updated at epoch 597 with val_loss=0.0157
#  Best weights updated at epoch 600 with val_loss=0.0157
#  Best weights updated at epoch 628 with val_loss=0.0157
#  Best weights updated at epoch 629 with val_loss=0.0156
#  Best weights updated at epoch 631 with val_loss=0.0156
#  Best weights updated at epoch 632 with val_loss=0.0156
#  Best weights updated at epoch 633 with val_loss=0.0156
#  Best weights updated at epoch 645 with val_loss=0.0156
#  Best weights updated at epoch 646 with val_loss=0.0156
#  Best weights updated at epoch 662 with val_loss=0.0156
#  Best weights updated at epoch 664 with val_loss=0.0156
#  Best weights updated at epoch 671 with val_loss=0.0155
#  Best weights updated at epoch 694 with val_loss=0.0155
#  Best weights updated at epoch 697 with val_loss=0.0155
#  Best weights updated at epoch 745 with val_loss=0.0155
#  Best weights updated at epoch 746 with val_loss=0.0154
#  Best weights updated at epoch 747 with val_loss=0.0154
#  Best weights updated at epoch 754 with val_loss=0.0154
#  Best weights updated at epoch 755 with val_loss=0.0154
#  Best weights updated at epoch 759 with val_loss=0.0153
#  Best weights updated at epoch 767 with val_loss=0.0153
#  Best weights updated at epoch 768 with val_loss=0.0153
#  Best weights updated at epoch 770 with val_loss=0.0153
#  Best weights updated at epoch 784 with val_loss=0.0153
#  Best weights updated at epoch 789 with val_loss=0.0152
#  Best weights updated at epoch 790 with val_loss=0.0152
#  Best weights updated at epoch 794 with val_loss=0.0152
#  Best weights updated at epoch 795 with val_loss=0.0152
#  Best weights updated at epoch 796 with val_loss=0.0152
#  Best weights updated at epoch 798 with val_loss=0.0152
#  Best weights updated at epoch 801 with val_loss=0.0152
#  Best weights updated at epoch 807 with val_loss=0.0152
#  Best weights updated at epoch 813 with val_loss=0.0152
#  Best weights updated at epoch 814 with val_loss=0.0152
#  Best weights updated at epoch 815 with val_loss=0.0152
#  Best weights updated at epoch 818 with val_loss=0.0151
#  Best weights updated at epoch 821 with val_loss=0.0151
#  Best weights updated at epoch 828 with val_loss=0.0151
#  Best weights updated at epoch 829 with val_loss=0.0151
#  Best weights updated at epoch 830 with val_loss=0.0151
#  Best weights updated at epoch 833 with val_loss=0.0151
#  Best weights updated at epoch 835 with val_loss=0.0151
#  Best weights updated at epoch 837 with val_loss=0.0151
#  Best weights updated at epoch 839 with val_loss=0.0151
#  Best weights updated at epoch 843 with val_loss=0.0151
#  Best weights updated at epoch 868 with val_loss=0.0150
#  Best weights updated at epoch 869 with val_loss=0.0150
#  Best weights updated at epoch 871 with val_loss=0.0150
#  Best weights updated at epoch 916 with val_loss=0.0149
#  Best weights updated at epoch 918 with val_loss=0.0149
#  Best weights updated at epoch 919 with val_loss=0.0147
#  Best weights updated at epoch 928 with val_loss=0.0147
#  Best weights updated at epoch 929 with val_loss=0.0147
#  Best weights updated at epoch 931 with val_loss=0.0147
#  Best weights updated at epoch 932 with val_loss=0.0146
#  Best weights updated at epoch 934 with val_loss=0.0146
#  Best weights updated at epoch 935 with val_loss=0.0146
#  Best weights updated at epoch 941 with val_loss=0.0145
#  Best weights updated at epoch 947 with val_loss=0.0145
#  Best weights updated at epoch 948 with val_loss=0.0145
#  Best weights updated at epoch 949 with val_loss=0.0144
#  Best weights updated at epoch 950 with val_loss=0.0144
#  Best weights updated at epoch 951 with val_loss=0.0144
#  Best weights updated at epoch 954 with val_loss=0.0144
#  Best weights updated at epoch 960 with val_loss=0.0143
#  Best weights updated at epoch 967 with val_loss=0.0143
#  Best weights updated at epoch 968 with val_loss=0.0142
#  Best weights updated at epoch 970 with val_loss=0.0141
#  Best weights updated at epoch 972 with val_loss=0.0141
#  Best weights updated at epoch 973 with val_loss=0.0141
#  Best weights updated at epoch 974 with val_loss=0.0140
#  Best weights updated at epoch 975 with val_loss=0.0140
#  Best weights updated at epoch 979 with val_loss=0.0138
#  Best weights updated at epoch 980 with val_loss=0.0136
#  Best weights updated at epoch 981 with val_loss=0.0136
#  Best weights updated at epoch 982 with val_loss=0.0135
#  Best weights updated at epoch 984 with val_loss=0.0135
#  Best weights updated at epoch 988 with val_loss=0.0133
#  Best weights updated at epoch 989 with val_loss=0.0131
# Restored best model from epoch after 100 with val_loss=0.0131
# 29/29 [==============================] - 3s 66ms/step
# 100%|██████████| 10/10 [25:28<00:00, 152.89s/it]

# %%
plt.semilogy(results[0]['history']['loss'])

# %%
# Time
mean_training_time = np.mean([res["training_time"] for res in results])
std_training_time = np.std([res["training_time"] for res in results])
mean_evaluation_time = np.mean([res["inference_time"] for res in results])
std_evaluation_time = np.std([res["inference_time"] for res in results])

print(f"Mean training time: {mean_training_time:.3f} s ± {std_training_time:.3f} s")
print(f"Mean evaluation time: {mean_evaluation_time:.3f} s ± {std_evaluation_time:.3f} s")
# Out:
# Mean training time: 149.841 s ± 7.018 s
# Mean evaluation time: 2.862 s ± 0.388 s

# %% [markdown]
# ## Predict

# %%
idx=4
preds = results[idx]["pred"]
g_int_test = results[idx]["g_test"]

plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 5, 20)]

fig2 = plt.figure(figsize = (10, 4), dpi=300)
fig2.suptitle('1D Stochastic PDE - DeepONet')

index = 0
for i in [39,66,77,99]:
    plt.plot(y_space, g_int_test[i,:,:,0], color=colors[index], label='Actual')
    plt.plot(y_space, g_int_test[i,:,:,1], color=colors[index], label='Actual')
    plt.plot(y_space, preds[i,:,0].T, '--', color=colors[index], label='Prediction')
    plt.plot(y_space, preds[i,:,1].T, '--', color=colors[index], label='Prediction')
    index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)
